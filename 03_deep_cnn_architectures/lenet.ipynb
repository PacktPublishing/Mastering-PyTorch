# %%
import numpy as np
import matplotlib.pyplot as plt
 
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms

torch.manual_seed(55)

# %%
class LeNet(nn.Module):

    def __init__(self):
        super(LeNet, self).__init__()
        # 3 input image channel, 6 output feature maps and 5x5 conv kernel
        self.cn1 = nn.Conv2d(3, 6, 5)
        # 6 input image channel, 16 output feature maps and 5x5 conv kernel
        self.cn2 = nn.Conv2d(6, 16, 5)
        # fully connected layers of size 120, 84 and 10
        self.fc1 = nn.Linear(16 * 5 * 5, 120)  # 5*5 is the spatial dimension at this layer
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        # Convolution with 5x5 kernel
        x = F.relu(self.cn1(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Convolution with 5x5 kernel
        x = F.relu(self.cn2(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Flatten spatial and depth dimensions into a single vector
        x = x.view(-1, self.flattened_features(x))
        # Fully connected operations
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def flattened_features(self, x):
        # all except the first (batch) dimension
        size = x.size()[1:]  
        num_feats = 1
        for s in size:
            num_feats *= s
        return num_feats


lenet = LeNet()
print(lenet)
# Out:
# LeNet(
#   (cn1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (cn2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
def train(net, trainloader, optim, epoch):
    # initialize loss
    loss_total = 0.0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        # ip refers to the input images, and ground_truth refers to the output classes the images belong to
        ip, ground_truth = data

        # zero the parameter gradients
        optim.zero_grad()

        # forward pass + backward pass + optimization step
        op = net(ip)
        loss = nn.CrossEntropyLoss()(op, ground_truth)
        loss.backward()
        optim.step()

        # update loss
        loss_total += loss.item()
        
        # print loss statistics
        if (i+1) % 1000 == 0:    # print at the interval of 1000 mini-batches
            print('[Epoch number : %d, Mini-batches: %5d] loss: %.3f' %
                  (epoch + 1, i + 1, loss_total / 200))
            loss_total = 0.0

# %%
def test(net, testloader):
    success = 0
    counter = 0
    with torch.no_grad():
        for data in testloader:
            im, ground_truth = data
            op = net(im)
            _, pred = torch.max(op.data, 1)
            counter += ground_truth.size(0)
            success += (pred == ground_truth).sum().item()

    print('LeNet accuracy on 10000 images from test dataset: %d %%' % (
        100 * success / counter))

# %%
# The mean and std are kept as 0.5 for normalizing pixel values as the pixel values are originally in the range 0 to 1
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.RandomCrop(32, 4),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=8, shuffle=True, num_workers=1)


test_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=10000, shuffle=False, num_workers=2)


# ordering is important
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# define a function that displays an image
def imageshow(image):
    # un-normalize the image
    image = image/2 + 0.5     
    npimage = image.numpy()
    plt.imshow(np.transpose(npimage, (1, 2, 0)))
    plt.show()


# sample images from training set
dataiter = iter(trainloader)
images, labels = dataiter.next()

# display images in a grid
num_images = 4
imageshow(torchvision.utils.make_grid(images[:num_images]))
# print labels
print('    '+'  ||  '.join(classes[labels[j]] for j in range(num_images)))
# Out:
#     dog  ||  cat  ||  horse  ||  bird

# %%
# define optimizer
optim = torch.optim.Adam(lenet.parameters(), lr=0.001)

# training loop over the dataset multiple times
for epoch in range(50):  
    train(lenet, trainloader, optim, epoch)
    print()
    test(lenet, testloader)
    print()

print('Finished Training')
# Out:
# [Epoch number : 1, Mini-batches:  1000] loss: 9.901
# [Epoch number : 1, Mini-batches:  2000] loss: 8.828
# [Epoch number : 1, Mini-batches:  3000] loss: 8.350
# [Epoch number : 1, Mini-batches:  4000] loss: 8.125
# [Epoch number : 1, Mini-batches:  5000] loss: 7.935
# [Epoch number : 1, Mini-batches:  6000] loss: 7.619
#
# LeNet accuracy on 10000 images from test dataset: 48 %
#
# [Epoch number : 2, Mini-batches:  1000] loss: 7.479
# [Epoch number : 2, Mini-batches:  2000] loss: 7.480
# [Epoch number : 2, Mini-batches:  3000] loss: 7.327
# [Epoch number : 2, Mini-batches:  4000] loss: 7.218
# [Epoch number : 2, Mini-batches:  5000] loss: 7.006
# [Epoch number : 2, Mini-batches:  6000] loss: 6.994
#
# LeNet accuracy on 10000 images from test dataset: 52 %
#
# [Epoch number : 3, Mini-batches:  1000] loss: 6.910
# [Epoch number : 3, Mini-batches:  2000] loss: 6.771
# [Epoch number : 3, Mini-batches:  3000] loss: 6.724
# [Epoch number : 3, Mini-batches:  4000] loss: 6.783
# [Epoch number : 3, Mini-batches:  5000] loss: 6.604
# [Epoch number : 3, Mini-batches:  6000] loss: 6.637
#
# LeNet accuracy on 10000 images from test dataset: 55 %
#
# [Epoch number : 4, Mini-batches:  1000] loss: 6.534
# [Epoch number : 4, Mini-batches:  2000] loss: 6.473
# [Epoch number : 4, Mini-batches:  3000] loss: 6.547
# [Epoch number : 4, Mini-batches:  4000] loss: 6.435
# [Epoch number : 4, Mini-batches:  5000] loss: 6.438
# [Epoch number : 4, Mini-batches:  6000] loss: 6.241
#
# LeNet accuracy on 10000 images from test dataset: 56 %
#
# [Epoch number : 5, Mini-batches:  1000] loss: 6.279
# [Epoch number : 5, Mini-batches:  2000] loss: 6.190
# [Epoch number : 5, Mini-batches:  3000] loss: 6.277
# [Epoch number : 5, Mini-batches:  4000] loss: 6.218
# [Epoch number : 5, Mini-batches:  5000] loss: 6.199
# [Epoch number : 5, Mini-batches:  6000] loss: 6.218
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 6, Mini-batches:  1000] loss: 6.079
# [Epoch number : 6, Mini-batches:  2000] loss: 6.133
# [Epoch number : 6, Mini-batches:  3000] loss: 6.035
# [Epoch number : 6, Mini-batches:  4000] loss: 6.089
# [Epoch number : 6, Mini-batches:  5000] loss: 6.024
# [Epoch number : 6, Mini-batches:  6000] loss: 5.966
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 7, Mini-batches:  1000] loss: 6.010
# [Epoch number : 7, Mini-batches:  2000] loss: 6.065
# [Epoch number : 7, Mini-batches:  3000] loss: 5.930
# [Epoch number : 7, Mini-batches:  4000] loss: 5.948
# [Epoch number : 7, Mini-batches:  5000] loss: 5.866
# [Epoch number : 7, Mini-batches:  6000] loss: 6.013
#
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 8, Mini-batches:  1000] loss: 5.846
# [Epoch number : 8, Mini-batches:  2000] loss: 5.833
# [Epoch number : 8, Mini-batches:  3000] loss: 5.829
# [Epoch number : 8, Mini-batches:  4000] loss: 5.825
# [Epoch number : 8, Mini-batches:  5000] loss: 5.906
# [Epoch number : 8, Mini-batches:  6000] loss: 5.912
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 9, Mini-batches:  1000] loss: 5.764
# [Epoch number : 9, Mini-batches:  2000] loss: 5.788
# [Epoch number : 9, Mini-batches:  3000] loss: 5.890
# [Epoch number : 9, Mini-batches:  4000] loss: 5.713
# [Epoch number : 9, Mini-batches:  5000] loss: 5.864
# [Epoch number : 9, Mini-batches:  6000] loss: 5.842
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 10, Mini-batches:  1000] loss: 5.583
# [Epoch number : 10, Mini-batches:  2000] loss: 5.746
# [Epoch number : 10, Mini-batches:  3000] loss: 5.724
# [Epoch number : 10, Mini-batches:  4000] loss: 5.720
# [Epoch number : 10, Mini-batches:  5000] loss: 5.644
# [Epoch number : 10, Mini-batches:  6000] loss: 5.839
#
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 11, Mini-batches:  1000] loss: 5.629
# [Epoch number : 11, Mini-batches:  2000] loss: 5.720
# [Epoch number : 11, Mini-batches:  3000] loss: 5.681
# [Epoch number : 11, Mini-batches:  4000] loss: 5.705
# [Epoch number : 11, Mini-batches:  5000] loss: 5.582
# [Epoch number : 11, Mini-batches:  6000] loss: 5.649
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 12, Mini-batches:  1000] loss: 5.699
# [Epoch number : 12, Mini-batches:  2000] loss: 5.533
# [Epoch number : 12, Mini-batches:  3000] loss: 5.753
# [Epoch number : 12, Mini-batches:  4000] loss: 5.541
# [Epoch number : 12, Mini-batches:  5000] loss: 5.585
# [Epoch number : 12, Mini-batches:  6000] loss: 5.587
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 13, Mini-batches:  1000] loss: 5.530
# [Epoch number : 13, Mini-batches:  2000] loss: 5.716
# [Epoch number : 13, Mini-batches:  3000] loss: 5.694
# [Epoch number : 13, Mini-batches:  4000] loss: 5.520
# [Epoch number : 13, Mini-batches:  5000] loss: 5.494
# [Epoch number : 13, Mini-batches:  6000] loss: 5.605
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 14, Mini-batches:  1000] loss: 5.449
# [Epoch number : 14, Mini-batches:  2000] loss: 5.573
# [Epoch number : 14, Mini-batches:  3000] loss: 5.559
# [Epoch number : 14, Mini-batches:  4000] loss: 5.658
# [Epoch number : 14, Mini-batches:  5000] loss: 5.462
# [Epoch number : 14, Mini-batches:  6000] loss: 5.556
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 15, Mini-batches:  1000] loss: 5.455
# [Epoch number : 15, Mini-batches:  2000] loss: 5.442
# [Epoch number : 15, Mini-batches:  3000] loss: 5.486
# [Epoch number : 15, Mini-batches:  4000] loss: 5.499
# [Epoch number : 15, Mini-batches:  5000] loss: 5.576
# [Epoch number : 15, Mini-batches:  6000] loss: 5.542
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 16, Mini-batches:  1000] loss: 5.511
# [Epoch number : 16, Mini-batches:  2000] loss: 5.411
# [Epoch number : 16, Mini-batches:  3000] loss: 5.488
# [Epoch number : 16, Mini-batches:  4000] loss: 5.475
# [Epoch number : 16, Mini-batches:  5000] loss: 5.384
# [Epoch number : 16, Mini-batches:  6000] loss: 5.496
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 17, Mini-batches:  1000] loss: 5.579
# [Epoch number : 17, Mini-batches:  2000] loss: 5.316
# [Epoch number : 17, Mini-batches:  3000] loss: 5.422
# [Epoch number : 17, Mini-batches:  4000] loss: 5.369
# [Epoch number : 17, Mini-batches:  5000] loss: 5.388
# [Epoch number : 17, Mini-batches:  6000] loss: 5.482
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 18, Mini-batches:  1000] loss: 5.465
# [Epoch number : 18, Mini-batches:  2000] loss: 5.409
# [Epoch number : 18, Mini-batches:  3000] loss: 5.441
# [Epoch number : 18, Mini-batches:  4000] loss: 5.509
# [Epoch number : 18, Mini-batches:  5000] loss: 5.439
# [Epoch number : 18, Mini-batches:  6000] loss: 5.317
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 19, Mini-batches:  1000] loss: 5.332
# [Epoch number : 19, Mini-batches:  2000] loss: 5.320
# [Epoch number : 19, Mini-batches:  3000] loss: 5.309
# [Epoch number : 19, Mini-batches:  4000] loss: 5.355
# [Epoch number : 19, Mini-batches:  5000] loss: 5.370
# [Epoch number : 19, Mini-batches:  6000] loss: 5.556
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 20, Mini-batches:  1000] loss: 5.324
# [Epoch number : 20, Mini-batches:  2000] loss: 5.336
# [Epoch number : 20, Mini-batches:  3000] loss: 5.342
# [Epoch number : 20, Mini-batches:  4000] loss: 5.324
# [Epoch number : 20, Mini-batches:  5000] loss: 5.421
# [Epoch number : 20, Mini-batches:  6000] loss: 5.383
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 21, Mini-batches:  1000] loss: 5.366
# [Epoch number : 21, Mini-batches:  2000] loss: 5.228
# [Epoch number : 21, Mini-batches:  3000] loss: 5.451
# [Epoch number : 21, Mini-batches:  4000] loss: 5.223
# [Epoch number : 21, Mini-batches:  5000] loss: 5.373
# [Epoch number : 21, Mini-batches:  6000] loss: 5.407
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 22, Mini-batches:  1000] loss: 5.242
# [Epoch number : 22, Mini-batches:  2000] loss: 5.296
# [Epoch number : 22, Mini-batches:  3000] loss: 5.342
# [Epoch number : 22, Mini-batches:  4000] loss: 5.323
# [Epoch number : 22, Mini-batches:  5000] loss: 5.342
# [Epoch number : 22, Mini-batches:  6000] loss: 5.378
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 23, Mini-batches:  1000] loss: 5.242
# [Epoch number : 23, Mini-batches:  2000] loss: 5.353
# [Epoch number : 23, Mini-batches:  3000] loss: 5.191
# [Epoch number : 23, Mini-batches:  4000] loss: 5.276
# [Epoch number : 23, Mini-batches:  5000] loss: 5.385
# [Epoch number : 23, Mini-batches:  6000] loss: 5.383
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 24, Mini-batches:  1000] loss: 5.288
# [Epoch number : 24, Mini-batches:  2000] loss: 5.339
# [Epoch number : 24, Mini-batches:  3000] loss: 5.234
# [Epoch number : 24, Mini-batches:  4000] loss: 5.262
# [Epoch number : 24, Mini-batches:  5000] loss: 5.345
# [Epoch number : 24, Mini-batches:  6000] loss: 5.266
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 25, Mini-batches:  1000] loss: 5.226
# [Epoch number : 25, Mini-batches:  2000] loss: 5.299
# [Epoch number : 25, Mini-batches:  3000] loss: 5.244
# [Epoch number : 25, Mini-batches:  4000] loss: 5.287
# [Epoch number : 25, Mini-batches:  5000] loss: 5.339
# [Epoch number : 25, Mini-batches:  6000] loss: 5.287
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 26, Mini-batches:  1000] loss: 5.251
# [Epoch number : 26, Mini-batches:  2000] loss: 5.217
# [Epoch number : 26, Mini-batches:  3000] loss: 5.228
# [Epoch number : 26, Mini-batches:  4000] loss: 5.378
# [Epoch number : 26, Mini-batches:  5000] loss: 5.251
# [Epoch number : 26, Mini-batches:  6000] loss: 5.306
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 27, Mini-batches:  1000] loss: 5.209
# [Epoch number : 27, Mini-batches:  2000] loss: 5.284
# [Epoch number : 27, Mini-batches:  3000] loss: 5.125
# [Epoch number : 27, Mini-batches:  4000] loss: 5.291
# [Epoch number : 27, Mini-batches:  5000] loss: 5.203
# [Epoch number : 27, Mini-batches:  6000] loss: 5.376
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 28, Mini-batches:  1000] loss: 5.162
# [Epoch number : 28, Mini-batches:  2000] loss: 5.108
# [Epoch number : 28, Mini-batches:  3000] loss: 5.308
# [Epoch number : 28, Mini-batches:  4000] loss: 5.340
# [Epoch number : 28, Mini-batches:  5000] loss: 5.209
# [Epoch number : 28, Mini-batches:  6000] loss: 5.170
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 29, Mini-batches:  1000] loss: 5.232
# [Epoch number : 29, Mini-batches:  2000] loss: 5.233
# [Epoch number : 29, Mini-batches:  3000] loss: 5.286
# [Epoch number : 29, Mini-batches:  4000] loss: 5.160
# [Epoch number : 29, Mini-batches:  5000] loss: 5.190
# [Epoch number : 29, Mini-batches:  6000] loss: 5.162
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 30, Mini-batches:  1000] loss: 5.093
# [Epoch number : 30, Mini-batches:  2000] loss: 5.221
# [Epoch number : 30, Mini-batches:  3000] loss: 5.206
# [Epoch number : 30, Mini-batches:  4000] loss: 5.108
# [Epoch number : 30, Mini-batches:  5000] loss: 5.185
# [Epoch number : 30, Mini-batches:  6000] loss: 5.237
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 31, Mini-batches:  1000] loss: 5.117
# [Epoch number : 31, Mini-batches:  2000] loss: 5.251
# [Epoch number : 31, Mini-batches:  3000] loss: 5.239
# [Epoch number : 31, Mini-batches:  4000] loss: 5.087
# [Epoch number : 31, Mini-batches:  5000] loss: 5.236
# [Epoch number : 31, Mini-batches:  6000] loss: 5.275
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 32, Mini-batches:  1000] loss: 5.248
# [Epoch number : 32, Mini-batches:  2000] loss: 5.131
# [Epoch number : 32, Mini-batches:  3000] loss: 5.190
# [Epoch number : 32, Mini-batches:  4000] loss: 5.120
# [Epoch number : 32, Mini-batches:  5000] loss: 5.069
# [Epoch number : 32, Mini-batches:  6000] loss: 5.186
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 33, Mini-batches:  1000] loss: 5.135
# [Epoch number : 33, Mini-batches:  2000] loss: 5.227
# [Epoch number : 33, Mini-batches:  3000] loss: 5.081
# [Epoch number : 33, Mini-batches:  4000] loss: 5.038
# [Epoch number : 33, Mini-batches:  5000] loss: 5.329
# [Epoch number : 33, Mini-batches:  6000] loss: 5.199
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 34, Mini-batches:  1000] loss: 5.254
# [Epoch number : 34, Mini-batches:  2000] loss: 5.179
# [Epoch number : 34, Mini-batches:  3000] loss: 5.089
# [Epoch number : 34, Mini-batches:  4000] loss: 5.220
# [Epoch number : 34, Mini-batches:  5000] loss: 5.155
# [Epoch number : 34, Mini-batches:  6000] loss: 5.121
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 35, Mini-batches:  1000] loss: 5.148
# [Epoch number : 35, Mini-batches:  2000] loss: 5.133
# [Epoch number : 35, Mini-batches:  3000] loss: 5.033
# [Epoch number : 35, Mini-batches:  4000] loss: 5.204
# [Epoch number : 35, Mini-batches:  5000] loss: 5.256
# [Epoch number : 35, Mini-batches:  6000] loss: 5.153
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 36, Mini-batches:  1000] loss: 4.985
# [Epoch number : 36, Mini-batches:  2000] loss: 4.995
# [Epoch number : 36, Mini-batches:  3000] loss: 5.231
# [Epoch number : 36, Mini-batches:  4000] loss: 5.290
# [Epoch number : 36, Mini-batches:  5000] loss: 5.163
# [Epoch number : 36, Mini-batches:  6000] loss: 5.180
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 37, Mini-batches:  1000] loss: 5.131
# [Epoch number : 37, Mini-batches:  2000] loss: 5.104
# [Epoch number : 37, Mini-batches:  3000] loss: 5.073
# [Epoch number : 37, Mini-batches:  4000] loss: 5.188
# [Epoch number : 37, Mini-batches:  5000] loss: 5.139
# [Epoch number : 37, Mini-batches:  6000] loss: 5.239
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 38, Mini-batches:  1000] loss: 5.138
# [Epoch number : 38, Mini-batches:  2000] loss: 4.995
# [Epoch number : 38, Mini-batches:  3000] loss: 5.038
# [Epoch number : 38, Mini-batches:  4000] loss: 5.062
# [Epoch number : 38, Mini-batches:  5000] loss: 5.201
# [Epoch number : 38, Mini-batches:  6000] loss: 5.099
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 39, Mini-batches:  1000] loss: 5.149
# [Epoch number : 39, Mini-batches:  2000] loss: 5.045
# [Epoch number : 39, Mini-batches:  3000] loss: 5.165
# [Epoch number : 39, Mini-batches:  4000] loss: 4.962
# [Epoch number : 39, Mini-batches:  5000] loss: 5.099
# [Epoch number : 39, Mini-batches:  6000] loss: 5.011
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 40, Mini-batches:  1000] loss: 5.008
# [Epoch number : 40, Mini-batches:  2000] loss: 5.173
# [Epoch number : 40, Mini-batches:  3000] loss: 5.058
# [Epoch number : 40, Mini-batches:  4000] loss: 5.191
# [Epoch number : 40, Mini-batches:  5000] loss: 5.093
# [Epoch number : 40, Mini-batches:  6000] loss: 5.035
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 41, Mini-batches:  1000] loss: 5.137
# [Epoch number : 41, Mini-batches:  2000] loss: 5.046
# [Epoch number : 41, Mini-batches:  3000] loss: 5.029
# [Epoch number : 41, Mini-batches:  4000] loss: 5.100
# [Epoch number : 41, Mini-batches:  5000] loss: 5.205
# [Epoch number : 41, Mini-batches:  6000] loss: 5.025
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 42, Mini-batches:  1000] loss: 5.045
# [Epoch number : 42, Mini-batches:  2000] loss: 5.100
# [Epoch number : 42, Mini-batches:  3000] loss: 5.020
# [Epoch number : 42, Mini-batches:  4000] loss: 5.105
# [Epoch number : 42, Mini-batches:  5000] loss: 5.085
# [Epoch number : 42, Mini-batches:  6000] loss: 5.083
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 43, Mini-batches:  1000] loss: 5.034
# [Epoch number : 43, Mini-batches:  2000] loss: 5.079
# [Epoch number : 43, Mini-batches:  3000] loss: 5.035
# [Epoch number : 43, Mini-batches:  4000] loss: 5.109
# [Epoch number : 43, Mini-batches:  5000] loss: 5.225
# [Epoch number : 43, Mini-batches:  6000] loss: 5.003
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 44, Mini-batches:  1000] loss: 5.218
# [Epoch number : 44, Mini-batches:  2000] loss: 5.037
# [Epoch number : 44, Mini-batches:  3000] loss: 5.089
# [Epoch number : 44, Mini-batches:  4000] loss: 5.055
# [Epoch number : 44, Mini-batches:  5000] loss: 4.880
# [Epoch number : 44, Mini-batches:  6000] loss: 4.988
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 45, Mini-batches:  1000] loss: 5.045
# [Epoch number : 45, Mini-batches:  2000] loss: 5.176
# [Epoch number : 45, Mini-batches:  3000] loss: 5.065
# [Epoch number : 45, Mini-batches:  4000] loss: 5.056
# [Epoch number : 45, Mini-batches:  5000] loss: 5.027
# [Epoch number : 45, Mini-batches:  6000] loss: 5.069
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 46, Mini-batches:  1000] loss: 5.070
# [Epoch number : 46, Mini-batches:  2000] loss: 5.017
# [Epoch number : 46, Mini-batches:  3000] loss: 5.150
# [Epoch number : 46, Mini-batches:  4000] loss: 5.067
# [Epoch number : 46, Mini-batches:  5000] loss: 5.146
# [Epoch number : 46, Mini-batches:  6000] loss: 5.015
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 47, Mini-batches:  1000] loss: 5.018
# [Epoch number : 47, Mini-batches:  2000] loss: 5.102
# [Epoch number : 47, Mini-batches:  3000] loss: 5.013
# [Epoch number : 47, Mini-batches:  4000] loss: 4.961
# [Epoch number : 47, Mini-batches:  5000] loss: 5.203
# [Epoch number : 47, Mini-batches:  6000] loss: 5.043
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 48, Mini-batches:  1000] loss: 5.120
# [Epoch number : 48, Mini-batches:  2000] loss: 5.102
# [Epoch number : 48, Mini-batches:  3000] loss: 5.133
# [Epoch number : 48, Mini-batches:  4000] loss: 4.997
# [Epoch number : 48, Mini-batches:  5000] loss: 5.036
# [Epoch number : 48, Mini-batches:  6000] loss: 5.114
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 49, Mini-batches:  1000] loss: 4.986
# [Epoch number : 49, Mini-batches:  2000] loss: 4.925
# [Epoch number : 49, Mini-batches:  3000] loss: 5.013
# [Epoch number : 49, Mini-batches:  4000] loss: 5.066
# [Epoch number : 49, Mini-batches:  5000] loss: 5.167
# [Epoch number : 49, Mini-batches:  6000] loss: 5.011
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 50, Mini-batches:  1000] loss: 5.027
# [Epoch number : 50, Mini-batches:  2000] loss: 5.143
# [Epoch number : 50, Mini-batches:  3000] loss: 5.079
# [Epoch number : 50, Mini-batches:  4000] loss: 5.159
# [Epoch number : 50, Mini-batches:  5000] loss: 5.065
# [Epoch number : 50, Mini-batches:  6000] loss: 4.977
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# Finished Training

# %%
model_path = './cifar_model.pth'
torch.save(lenet.state_dict(), model_path)

# %%
im[:4].shape
# Out:
# torch.Size([4, 3, 32, 32])

# %%
# load test dataset images
d_iter = iter(testloader)
im, ground_truth = d_iter.next()

# print images and ground truth
imageshow(torchvision.utils.make_grid(im[:4]))
print('Label:      ', ' '.join('%5s' % classes[ground_truth[j]] for j in range(4)))

# load model
lenet_cached = LeNet()
lenet_cached.load_state_dict(torch.load(model_path))

# model inference
op = lenet_cached(im)

# print predictions
_, pred = torch.max(op, 1)

print('Prediction: ', ' '.join('%5s' % classes[pred[j]] for j in range(4)))
# Out:
# Label:         cat  ship  ship plane
# Prediction:    cat  ship  ship plane

# %%
success = 0
counter = 0
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op.data, 1)
        counter += ground_truth.size(0)
        success += (pred == ground_truth).sum().item()

print('Model accuracy on 10000 images from test dataset: %d %%' % (
    100 * success / counter))
# Out:
# Model accuracy on 10000 images from test dataset: 67 %

# %%
class_sucess = list(0. for i in range(10))
class_counter = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op, 1)
        c = (pred == ground_truth).squeeze()
        for i in range(10000):
            ground_truth_curr = ground_truth[i]
            class_sucess[ground_truth_curr] += c[i].item()
            class_counter[ground_truth_curr] += 1


for i in range(10):
    print('Model accuracy for class %5s : %2d %%' % (
        classes[i], 100 * class_sucess[i] / class_counter[i]))
# Out:
# Model accuracy for class plane : 68 %
# Model accuracy for class   car : 87 %
# Model accuracy for class  bird : 57 %
# Model accuracy for class   cat : 56 %
# Model accuracy for class  deer : 59 %
# Model accuracy for class   dog : 39 %
# Model accuracy for class  frog : 83 %
# Model accuracy for class horse : 62 %
# Model accuracy for class  ship : 82 %
# Model accuracy for class truck : 75 %
