# %% [markdown]
# ## download data

# %%
# linux
# !apt-get install wget
# mac
# !brew install wget
 
# create a data directory
# !mkdir data_dir
 
# download images and annotations to the data directory
# !wget http://msvocds.blob.core.windows.net/annotations-1-0-3/captions_train-val2014.zip -P ./data_dir/
# !wget http://images.cocodataset.org/zips/train2014.zip -P ./data_dir/
# !wget http://images.cocodataset.org/zips/val2014.zip -P ./data_dir/
    
# extract zipped images and annotations and remove the zip files
# !unzip ./data_dir/captions_train-val2014.zip -d ./data_dir/
# !rm ./data_dir/captions_train-val2014.zip
# !unzip ./data_dir/train2014.zip -d ./data_dir/
# !rm ./data_dir/train2014.zip 
# !unzip ./data_dir/val2014.zip -d ./data_dir/ 
# !rm ./data_dir/val2014.zip
# Out:
# /bin/sh: apt-get: command not found
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# acl2                       gateway-go                 ormolu
# act                        git-hooks-go               ory-hydra
# apidoc                     go@1.14                    osi
# arb                        golangci-lint              osm
# argo                       gostatic                   pandocomatic
# argocd                     gradle-profiler            parallel-hashmap
# arrayfire                  gulp-cli                   periscope
# athenacli                  httpx                      pipgrip
# bond                       hy                         podman
# borgbackup                 infracost                  promtail
# c7n                        inja                       protoc-gen-gogo
# cadence                    ioctl                      protoc-gen-gogofaster
# castget                    jimtcl                     python@3.7
# cbc                        jinx                       reg
# cdktf                      jsonnet-bundler            rqlite
# cgl                        kona                       scw@1
# chalk-cli                  kondo                      sdns
# charge                     ksync                      shallow-backup
# chart-testing              kubie                      sheldon
# chrony                     ldpl                       silicon
# clair                      libirecovery               simdjson
# clang-format@8             libseccomp                 sleef
# cli11                      litecli                    snap
# coconut                    localstack                 so
# copilot                    logcli                     solidity
# cortex                     loki                       sponge
# croaring                   lunchy                     sqlite-utils
# croc                       lunchy-go                  staticcheck
# cubejs-cli                 mariadb@10.4               subfinder
# datasette                  marked                     termcolor
# dbdeployer                 mhonarc                    terraform@0.12
# diskonaut                  microplane                 terrascan
# dnsprobe                   naabu                      thanos
# dosbox-staging             nanorc                     torchvision
# duckscript                 never                      ugrep
# eksctl                     nfpm                       usb.ids
# eleventy                   ngs                        volk
# empty                      notmuch-mutt               vtk@8.2
# fennel                     numcpp                     wgcf
# fetch                      oci-cli                    wownero
# folderify                  omake                      yj
# functionalplus             openfst                    z.lua
# ==> Updated Formulae
# Updated 3729 formulae.
# ==> Renamed Formulae
# elasticsearch@6.8 -> elasticsearch@6     kibana@6.8 -> kibana@6
# ==> Deleted Formulae
# python ✔            elasticsearch@2.4   kibana@5.6          wpscan
# cargo-completion    elasticsearch@5.6   sflowtool
# cryptopp            i386-elf-grub       tomee-jax-rs
# ==> New Casks
# 8bitdo-ultimate-software                 marathon2
# 8x8-meet                                 mcreator
# aleph-one                                microsoft-auto-update
# amd-power-gadget                         moose
# apparency                                mqttx
# aws-vpn-client                           mumu
# bluejeans                                naver-whale
# bluetility                               nocturn
# box-tools                                openphone
# camo-studio                              pb
# cisco-jabber                             pcoipclient
# clash-for-windows                        pdf-over
# cloudflare-warp                          phd2
# colorchecker-camera-calibration          project-slippi-dolphin
# daedalus-mainnet                         raiderio
# dteoh-devdocs                            removebg
# edenmath                                 repoz
# element                                  river-sparkle
# fastclicker                              screenfocus
# fellow                                   sessionrestore
# filemaker-pro                            silnite
# fing-cli                                 sim-genie
# flutter                                  slimhud
# flying-carpet                            stageplotpro
# fme                                      strawberry-wallpaper
# gitpigeon                                sunloginclient
# google-analytics-opt-out                 surfshark
# gotomeeting                              syncroom
# hermit-crab                              timche-gmail-desktop
# hessenbox-da                             toggl-track
# icollections                             toolreleases
# jabt-flow                                transcribe
# jamulus                                  twilioquest
# joshjon-nocturnal                        unnaturalscrollwheels
# kdiff3                                   usenapp
# keysmith                                 vb-cable
# klogg                                    vipriser
# koodo-reader                             voov-meeting
# ksnip                                    weakauras-companion
# leela                                    webots
# locklizard-safeguard-viewer              windocd
# macintoshjs                              wondershare-uniconverter
# macjournal                               zbuc-imgur
# marathon-infinity                        zprint
# ==> Updated Casks
# google-cloud-sdk ✔
# 0-ad
# 010-editor
# 0xed
# 115browser
# 1clipboard
# 1password
# 1password-cli
# 360safe
# 3cxphone
# 3dgenceslicer
# 4k-slideshow-maker
# 4k-stogram
# 4k-video-downloader
# 4k-video-to-mp3
# 4k-youtube-to-mp3
# 4peaks
# 5kplayer
# a-better-finder-attributes
# a-better-finder-rename
# a-slower-speed-of-light
# ableton-live
# ableton-live-intro
# ableton-live-lite
# ableton-live-standard
# ableton-live-suite
# abricotine
# abscissa
# abstract
# accessmenubarapps
# accurics
# ace-link
# acorn
# acousticbrainz-gui
# acquia-dev
# acronis-true-image
# acslogo
# activedock
# activitywatch
# actual-odbc-pack
# adafruit-arduino
# adapter
# adguard
# adium
# adobe-acrobat-pro
# adobe-acrobat-reader
# adobe-air
# adobe-air-sdk
# adobe-connect
# adobe-creative-cloud
# adobe-creative-cloud-cleaner-tool
# adobe-digital-editions
# adobe-dng-converter
# adobe-lens-profile-creator
# adoptopenjdk
# advancedrestclient
# adventure
# adware-removal-tool
# aegisub
# aerial
# aether
# aexol-remote-mouse
# after-dark-classic
# agenda
# agfeo-dashboard
# aimersoft-video-converter-ultimate
# air-connect
# air-video-server-hd
# aircall
# airdisplay
# airdroid
# airflow
# airfoil
# airmedia
# airparrot
# airpass
# airqmon
# airserver
# airtable
# airtame
# airtool
# airtrash
# airunlock
# airy
# aja-system-test
# alacritty
# aladin
# alchemy
# alfaview
# alfred
# algodoo
# alinof-timer
# aliwangwang
# aliworkbench
# all-in-one-messenger
# alloy
# alt-c
# alt-tab
# altair-graphql-client
# altdeploy
# alternote
# altserver
# alva
# amadeus-pro
# amadine
# amazon-chime
# amazon-music
# amazon-photos
# amazon-workdocs
# amazon-workspaces
# amethyst
# amitv87-pip
# amm
# ammonite
# amorphousdiskmark
# ampps
# anaconda
# ananas-analytics-desktop-edition
# android-file-transfer
# android-messages
# android-ndk
# android-platform-tools
# android-sdk
# android-studio
# androidtool
# angband
# angry-ip-scanner
# anka-flow
# anki
# ankiapp-anki
# anonym
# anonymousvpn
# another-redis-desktop-manager
# ansible-dk
# antconc
# anvil
# anybar
# anydesk
# anydo
# anylist
# anytrans
# anytrans-for-android
# anzeigenchef
# ao
# apache-couchdb
# apache-directory-studio
# apk-icon-editor
# app-cleaner
# app-tamer
# appcleaner
# appcode
# appdelete
# appgate-sdp-client
# appgrid
# appium
# apple-events
# apple-juice
# applepi-baker
# apppolice
# appstore-quickview
# appstudio
# apptivate
# apptrap
# appzapper
# aptanastudio
# aptible
# aqua-data-studio
# aquamacs
# aquaskk
# aquaterm
# araxis-merge
# archipelago
# archiver
# arduino
# aria-maestosa
# aria2d
# aria2gui
# ariang
# ark-desktop-wallet
# armitage
# armory
# arq
# arq-cloud-backup
# arrayfire
# arrsync
# art-directors-toolkit
# artisan
# artpip
# asc-timetables
# ascension
# asciidocfx
# aspera-connect
# asset-catalog-tinkerer
# astah-professional
# astro-command-center
# astropad
# astropad-studio
# atext
# atlantis
# atlauncher
# atok
# atom
# au-lab
# audio-hijack
# audiobook-builder
# audiobookbinder
# audioscrobbler
# audioslicer
# audirvana
# augur
# auristor-client
# aurora
# aurora-hdr
# auryo
# authy
# autodesk-fusion360
# autodmg
# autofirma
# automute
# autopkgr
# autovolume
# autumn
# avast-secureline-vpn
# avast-security
# avg-antivirus
# aviatrix-vpn-client
# avibrazil-rdm
# avidcodecsle
# avidemux
# avira-antivirus
# avitools
# avocode
# avogadro
# awa
# aware
# awareness
# awips-python
# aws-vault
# axe-edit-iii
# axe-electrum
# axure-rp
# azure-data-studio
# babeledit
# back-in-time
# backblaze
# backblaze-downloader
# background-music
# backlog
# backuploupe
# badlion-client
# baiducloud
# baiduinput
# baidunetdisk
# balance-lock
# balenaetcher
# ballast
# balsamiq-wireframes
# bandage
# bankid
# banking-4
# banktivity
# banshee
# baretorrent
# baritone
# barrier
# bartender
# barxtemp
# base
# basecamp
# basictex
# batchmod
# bathyscaphe
# batteries
# battery-guardian
# battery-report
# battle-net
# battlescribe
# baudline
# bbc-iplayer-downloads
# bbedit
# bdash
# bdinfo
# beacon-scanner
# beaker-browser
# beamer
# bean
# beardedspice
# bearychat
# beatport-pro
# beatunes
# beautune
# bee
# beekeeper-studio
# beersmith
# beoplay-software-update
# bestres
# betaflight-configurator
# better-window-manager
# bettertouchtool
# betterzip
# between
# betwixt
# beyond-compare
# bfxr
# bibdesk
# big-mean-folder-machine
# bilibili
# bilimini
# binary-ninja
# bingpaper
# bino
# biopassfido
# birdfont
# biscuit
# bisq
# bit-slicer
# bitbar
# bitcoin-core
# bitmessage
# bitrix24
# bitshares
# bitwarden
# bitwig-studio
# blackhole
# blender
# blheli-configurator
# blink1control
# blisk
# blitz
# blizz
# blobby-volley2
# blockblock
# blockstack
# blocs
# bloodhound
# bloomrpc
# blooo
# blu-ray-player
# blu-ray-player-pro
# blue-jeans-browser-plugin
# bluefish
# bluegriffon
# blueharvest
# bluej
# bluesense
# bluestacks
# blurred
# bob
# boinc
# bonitastudiocommunity
# bonjeff
# bonjour-browser
# bookends
# bookmacster
# boom
# boom-3d
# boonzi
# boop
# boostnote
# bootchamp
# bootstrap-studio
# bootxchanger
# bossa
# bot-framework-emulator
# bowtie
# box-drive
# box-notes
# box-sync
# boxcryptor
# boxer
# boxofsnoo-fairmount
# boxy-suite
# brackets
# brain-workshop
# brainfm
# brave-browser
# breakaway
# breaktimer
# brewservicesmenubar
# brewtarget
# bria
# bricklink-partdesigner
# bricklink-studio
# bricksmith
# brightness
# brightness-sync
# brisk
# brisync
# brl-cad-mged
# brogue
# brook
# brooklyn
# browserosaurus
# browserstacklocal
# btcpayserver-vault
# bubo
# buildsettingextractor
# bunch
# bunqcommunity-bunq
# burn
# burp-suite
# busycal
# busycontacts
# butler
# butt
# butter
# buttercup
# bwana
# bzflag
# c0re100-qbittorrent
# cabal
# cacher
# caffeine
# cajviewer
# cakebrew
# calcservice
# calendar-366
# calibre
# camed
# camera-live
# camerabag-photo
# camtasia
# camunda-modeler
# canary
# candybar
# cantata
# caprine
# captain
# captin
# caption
# capto
# carbon-copy-cloner
# cardhop
# caret
# cashnotify
# catalina-cache-cleaner
# catch
# catlight
# cave-story
# ccleaner
# ccmenu
# cctalk
# cd-to
# celestialteapot-runway
# celldesigner
# cellery
# cellprofiler
# cemu
# cerebro
# cevelop
# chai
# chalk
# chameleon-ssd-optimizer
# charles
# charlessoft-timetracker
# chatmate-for-facebook
# chatmate-for-whatsapp
# chatology
# chatty
# chatwork
# cheatsheet
# checkra1n
# cheetah3d
# chef-workstation
# chemdoodle
# chessx
# chiaki
# chicken
# chirp
# chocolat
# choosy
# chrome-devtools
# chrome-remote-desktop-host
# chromedriver
# chromium
# chronicle
# chronoagent
# chronos
# chronosync
# chronycontrol
# chrysalis
# cinch
# cinder
# cinebench
# cisco-proximity
# cisdem-data-recovery
# cisdem-document-reader
# cisdem-pdf-converter-ocr
# cisdem-pdfmanagerultimate
# cisdem-pdftoolkit
# citra
# cityofzion-neon
# ckan
# ckb-next
# clamxav
# clashx
# clashxr
# classroom-assistant
# clean-me
# cleanapp
# cleanmymac
# cleanshot
# cleartext
# clementine
# clickcharts
# clickup
# clion
# clip-studio-paint
# clipbuddy
# clipgrab
# clipy
# cliqz
# clix
# cljstyle
# clock
# clock-bar
# clockify
# clocksaver
# clone-hero
# clonk
# cloud-pbx
# cloudapp
# cloudcompare
# cloudmounter
# cloudup
# cloudytabs
# clover-configurator
# cmake
# cmd-eikana
# cmdtap
# cncjs
# cncnet
# coccinellida
# coccoc
# cockatrice
# cocktail
# cocoapods
# cocoarestclient
# cocoaspell
# coconutbattery
# coconutid
# coda
# code-notes
# code42-crashplan
# codeexpander
# codekit
# codelite
# coderunner
# codespace
# cold-turkey-blocker
# collabshot
# color-oracle
# colormunki-photo
# colorpicker-developer
# colorpicker-materialdesign
# colorpicker-propicker
# colorpicker-skalacolor
# colorsnapper
# colortester
# colour-contrast-analyser
# combine-pdfs
# comictagger
# comma-chameleon
# command-tab-plus
# commander-one
# commandq
# comparemerge
# composercat
# compositor
# conferences
# connectiq
# connectmenow
# console
# container-ps
# contexts
# continuity-activation-tool
# contraste
# controllermate
# controlplane
# cookie
# cool-retro-term
# coolterm
# copyclip
# copyq
# coqide
# cord
# core-data-editor
# corelocationcli
# cornercal
# cornerstone
# corona-tracker
# coronasdk
# corretto
# coteditor
# couchbase-server-community
# couchbase-server-enterprise
# couchpotato
# couleurs
# countdown
# coverload
# cozy-drive
# cpuinfo
# cr
# craftmanager
# create-recovery-partition-installer
# createuserpkg
# creepy
# cricut-design-space
# criptext
# cronnix
# crossover
# crosspack-avr
# crunch
# crushftp
# cryo
# crypt
# crypter
# cryptomator
# cryptr
# crystalmaker
# crystax-ndk
# cscreen
# cubicsdr
# cuda-z
# cumulus
# cura-lulzbot
# curio
# cursorcerer
# cursorsense
# customshortcuts
# cuteclips
# cutesdr
# cutter
# cyberduck
# cyberghost-vpn
# cycling74-max
# cytoscape
# daedalus
# daisydisk
# dangerzone
# darktable
# darwindumper
# dash
# dash-dash
# dashcam-viewer
# dashlane
# dat
# data-integration
# data-rescue
# data-science-studio
# datadog-agent
# datagraph
# datagrip
# datazenit
# datovka
# datweatherdoe
# davmail
# day-o
# db-browser-for-sqlite
# dbeaver-community
# dbeaver-enterprise
# dbglass
# dbkoda
# dbngin
# dbschema
# dbvisualizer
# dcommander
# dcp-o-matic
# dcp-o-matic-batch-converter
# dcp-o-matic-encode-server
# dcp-o-matic-kdm-creator
# dcp-o-matic-player
# dcv-viewer
# dd-utility
# deadbolt
# deathtodsstore
# debookee
# deckset
# deco
# decrediton
# deeper
# deepgit
# deepl
# deepstream
# deezer
# default-folder-x
# dejalu
# delayedlauncher
# delicious-library
# delta
# deltawalker
# deluge
# dendroscope
# denemo
# desktoputility
# desmume
# detectx-swift
# detexify
# devdocs
# developerexcuses
# devolo-cockpit
# devonagent
# devonthink
# dexed
# dhs
# dia
# dialpad
# diashapes
# dictater
# dictcc-en-de-dictionary-plugin
# dictionaries
# dictunifier
# difffork
# diffmerge
# digikam
# dingtalk
# disablemonitor
# discord
# discretescroll
# disk-arbitrator
# disk-drill
# disk-inventory-x
# diskcatalogmaker
# diskmaker-x
# diskwave
# displaperture
# displaycal
# dissenter-browser
# divvy
# djay-pro
# djv
# djview
# dmenu-mac
# dmm-player
# dmm-player-for-chrome
# do-not-disturb
# docear
# docker
# docker-toolbox
# dockey
# dockstation
# dogecoin
# dolphin
# doly
# domainbrain
# doomrl
# doomsday-engine
# dosbox
# dosbox-x
# doteditor
# dotnet
# dotnet-sdk
# double-commander
# doubletwist
# downie
# doxie
# doxygen
# dozer
# dragthing
# drama
# drawbot
# drawio
# dremel-slicer
# drivedx
# drivethrurpg
# droidid
# drop-to-gif
# dropbox
# dropdmg
# dropletmanager
# droplr
# dropshare
# duckietv
# duefocus
# duet
# dukto
# dungeon-crawl-stone-soup-console
# dungeon-crawl-stone-soup-tiles
# duo-connect
# dupeguru
# duplicacy
# duplicacy-web-edition
# duplicate-annihilator-for-photos
# duplicati
# dupscanub
# dust3d
# dusty
# dvdstyler
# dwarf-fortress
# dwarf-fortress-lmp
# dwgsee
# dwihn0r-keepassx
# dyn-updater
# dynalist
# dynamic-dark-mode
# dynamodb-local
# dynobase
# eaccess
# eagle
# eaglefiler
# ealeksandrov-cd-to
# easy-move-plus-resize
# easyeda
# easyfind
# easytether
# ebibookreader
# ebmac
# eclipse-cpp
# eclipse-dsl
# eclipse-ide
# eclipse-installer
# eclipse-java
# eclipse-javascript
# eclipse-jee
# eclipse-modeling
# eclipse-php
# eclipse-platform
# eclipse-rcp
# eclipse-testing
# eddie
# edex-ui
# edfbrowser
# editaro
# edrawmax
# eggplant
# eiskaltdcpp
# ejector
# elan
# elasticwolf
# electerm
# electorrent
# electric-sheep
# electrocrud
# electron
# electron-api-demos
# electron-cash
# electron-fiddle
# electronic-wechat
# electronmail
# electrum
# electrum-ltc
# electrumsv
# elgiganten-jotta
# elmedia-player
# eloston-chromium
# elpass
# emacs
# emacsclient
# emailchemy
# emby-server
# emclient
# eme
# emojipedia
# empoche
# encryptme
# encryptr
# endless-sky
# endnote
# endurance
# energia
# energybar
# enfusegui
# engine-prime
# enjoyable
# enpass
# entropy
# envkey
# enzymex
# epic
# epic-games
# epichrome
# epoch-flip-clock
# epub-to-pdf
# epubmdimporter
# epubquicklook
# eqmac
# eset-cyber-security-pro
# espresso
# ethereum-wallet
# etrecheckpro
# eudic
# eurkey
# eve-launcher
# eventstore
# evernote
# everweb
# evolve-ip-uc-one
# evom
# exactscan
# exfalso
# exifrenamer
# exist-db
# exodus
# expandrive
# explorer
# expo-xde
# expressions
# expressscribe
# expressvpn
# extraterm
# ezip
# facebook-ios-sdk
# factor
# fake
# falcon-sql-client
# family-tree-builder
# fanny
# fantastical
# fantasy-grounds
# fantasy-map-generator
# farrago
# fastonosql
# fastrawviewer
# fastscripts
# fauxpas
# favro
# faxbot
# fbreader
# fedora-media-writer
# feed-the-beast
# feem
# feishu
# fenix
# ferdi
# fetch
# ff-works
# figma
# figmadaemon
# figtree
# fiji
# file-juicer
# filebot
# filedrop
# filemon
# filepane
# final-cut-library-manager
# find-any-file
# find-empty-folders
# findergo
# finereader
# fing
# finicky
# firealpaca
# firebase-admin
# firebird-emu
# firecamp
# firefox
# firestorm
# firestormos
# fireworks
# fiscript
# fission
# fitbit-os-simulator
# fl-studio
# flame
# flash-decompiler-trillix
# flash-npapi
# flash-player
# flash-player-debugger
# flash-player-debugger-npapi
# flash-player-debugger-ppapi
# flash-ppapi
# flashlighttool
# fldigi
# flexiglass
# flic
# flickr-uploadr
# flightgear
# flip4mac
# flipper
# fliqlo
# flirc
# flixtools
# flock
# flotato
# flow
# flow-e
# flowdock
# flowsync
# fluid
# flume
# fluor
# flux
# fluxcenter
# flvcd-bigrats
# fly
# flycut
# fm3-edit
# fman
# focus
# focus-booster
# focusatwill
# focused
# focuswriter
# fog
# folding-at-home
# foldingtext
# foldit
# folx
# fontbase
# fontexplorer-x-pro
# fontforge
# fontgoggles
# fontlab
# fontplop
# fontstand
# force-paste
# forecast
# foreman
# fork
# forklift
# forticlient
# foxitreader
# foxmail
# fpcsrc
# fractal-bot
# fraise
# framer
# framer-x
# franz
# freac
# fredm-fuse
# free-download-manager
# free-ruler
# freecad
# freecol
# freedom
# freedome
# freemind
# freenettray
# freeorion
# freeplane
# freesmug-chromium
# freeter
# freetube
# freeyourmusic
# freeze
# frescobaldi
# frhelper
# fritzing
# fromscratch
# front
# fs-uae
# fsmonitor
# fsnotes
# fstream
# fugu
# functionflip
# funter
# fuse
# futuniuniu
# fuwari
# fuzzyclock
# g-desktop-suite
# gameranger
# gameshow
# ganache
# ganttproject
# garagebuy
# garagesale
# gargoyle
# gas-mask
# gb-studio
# gcc-arm-embedded
# gcollazo-mongodb
# gdisk
# gdlauncher
# geany
# gearboy
# gearsystem
# geburtstagschecker
# geekbench
# geektool
# gemini
# geneious-prime
# genymotion
# geogebra
# geomap
# geotag
# geotag-photos-pro
# geotagger
# geph
# gephi
# get-backup-pro
# get-iplayer-automator
# get-lyrical
# getrasplex
# gfortran
# gfxcardstatus
# ghdl
# ghidra
# ghost-browser
# ghosttile
# gifcapture
# gifox
# gifrocket
# gifs
# gimp
# gingko
# gisto
# git-it
# gitahead
# gitblade
# gitbook
# gitbox
# gitee
# giteye
# gitfiend
# gitfinder
# gitfox
# github
# githubpulse
# gitify
# gitkraken
# gitnote
# gitscout
# gitter
# gitup
# gitx
# glance
# glimmerblocker
# globalmeet
# gloomhaven-helper
# gltfquicklook
# glyphfinder
# glyphs
# gmail-notifier
# gmvault
# gns3
# gnucash
# go-agent
# go-server
# go2shell
# go64
# gobdokumente
# godot
# godot-mono
# gog-galaxy
# gogs
# goland
# goldencheetah
# goldendict
# golly
# goodsync
# goofy
# google-ads-editor
# google-backup-and-sync
# google-chat
# google-chrome
# google-drive-file-stream
# google-earth-pro
# google-featured-photos
# google-hangouts
# google-japanese-ime
# google-photos-backup-and-sync
# google-trends
# google-web-designer
# googleappengine
# gopanda
# gopass-ui
# gotiengviet
# gpg-suite
# gpg-suite-no-mail
# gpg-suite-pinentry
# gpg-sync
# gplates
# gpodder
# gpower
# gps4cam
# gpxsee
# gqrx
# grads
# grafx
# grammarly
# gramps
# grandperspective
# grandtotal
# graphicconverter
# graphiql
# graphql-ide
# graphql-playground
# graphsketcher
# gray
# greenfoot
# gretl
# grid-clock
# gridea
# grids
# grisbi
# growlnotify
# gswitch
# gtkwave
# guijs
# guild-wars2
# guitar-pro
# gulp
# guppy
# gureumkim
# gyazmail
# gyazo
# gzdoom
# ha-menu
# hacker-menu
# hackhands
# hackintool
# hackmd
# hakuneko
# hammerspoon
# hancock
# hand-mirror
# handbrake
# handbrakebatch
# hands-off
# handshaker
# handylock
# happygrep
# haptic-touch-bar
# haptickey
# harbor
# harmony
# haroopad
# harvest
# hashbackup
# hazel
# hazeover
# hbuilder
# hbuilderx
# hdrmerge
# headset
# heaven
# hedgewars
# heimdall-suite
# helium
# hermes
# hex
# hex-fiend
# hey
# hfsleuth
# hiarcs-chess-explorer
# hiddenbar
# historyhound
# hma-pro-vpn
# hockey
# hocus-focus
# holavpn
# home-inventory
# honer
# honto
# hookshot
# hopper-debugger-server
# horndis
# horos
# hotswitch
# houdahspot
# houseparty
# hp-eprint
# hp-prime
# hstracker
# http-toolkit
# hubic
# hubstaff
# hue-topia
# hugin
# hwsensors
# hydrogen
# hype
# hyper
# hyperbackupexplorer
# hyperdock
# hyperswitch
# i1profiler
# ibabel
# ibackup
# ibackup-viewer
# ibackupbot
# ibettercharge
# ibm-cloud-cli
# ibored
# icab
# icanhazshortcut
# icc
# iceberg
# icefloor
# icestudio
# icloud-control
# iconizer
# iconjar
# icons
# icons8
# icq
# id3-editor
# idafree
# idagio
# idefrag
# idisplay
# idrive
# ieasemusic
# iexplorer
# ifunbox
# igdm
# igetter
# iglance
# igv
# iina
# iina-plus
# ilok-license-manager
# ilya-birman-typography-layout
# image-tool
# image2icon
# imagealpha
# imagej
# imagemin
# imageoptim
# imazing
# imazing-mini
# imgotv
# imitone
# imo
# impactor
# inav-configurator
# inboard
# indigo
# infoflow
# inform
# inkdrop
# inkscape
# inky
# inloop-qlplayground
# insomnia
# insomnia-designer
# inssider
# install-disk-creator
# instant-articles-builder
# instasizer
# insync
# integrity
# intel-haxm
# intel-power-gadget
# intel-psxe-ce-c-plus-plus
# intellij-idea
# intellij-idea-ce
# interarchy
# intune-company-portal
# invesalius
# invisiblix
# invisionsync
# invisor-lite
# inxmail-professional
# iograph
# ionic-lab
# ioquake3
# ios-app-signer
# ios-console
# ios-saver
# iota-wallet
# ip-in-menu-bar
# ipa-manager
# ipartition
# ipe
# ipepresenter
# ipfs
# iphoto-library-manager
# ipremoteutility
# ipsecuritas
# ipvanish-vpn
# ipynb-quicklook
# irccloud
# ireadfast
# iridient-developer
# iridium
# irip
# iris
# iriunwebcam
# isabelle
# ishowu
# ishowu-instant
# isimulator
# islide
# isolator
# istat-menus
# istat-server
# isteg
# istumbler
# isubtitle
# iswiff
# isyncr
# itau
# itch
# iterm2
# ithoughtsx
# itk-snap
# itools
# itrash
# itsycal
# itubedownloader
# itunes-producer
# itunes-volume-control
# ivideonclient
# ivideonserver
# ivolume
# ivpn
# izip
# j
# jabref
# jad
# jaikoz
# jaksta-media-recorder
# jalbum
# jalview
# jameica
# james
# jamf-migrator
# jami
# jamovi
# jandi
# jasp
# jasper
# java
# jaxx-liberty
# jazzup
# jbidwatcher
# jbrowse
# jclasslib-bytecode-viewer
# jcryptool
# jd-gui
# jdiskreport
# jdk-mission-control
# jdownloader
# jedit
# jedit-omega
# jellyfin
# jenkins-menu
# jeromelebel-mongohub
# jet
# jetbrains-toolbox
# jettison
# jewelrybox
# jgrasp
# jietu
# jiggler
# jing
# jira-client
# jitouch
# jitsi
# jitsi-meet
# jmc
# joinme
# joker
# jollysfastvnc
# joplin
# josm
# journey
# jprofiler
# jqbx
# jsui
# jtool
# jtool2
# jubler
# juicebar
# julia
# jump
# jumpcut
# jumpshare
# jupyter-notebook-ql
# jupyter-notebook-viewer
# kactus
# kafka-tool
# kakapo
# kaku
# kaleidoscope
# kap
# kapitainsky-rclone-browser
# kapow
# karabiner-elements
# katalon-studio
# katana
# kawa
# keep
# keep-it
# keepassx
# keepassxc
# keeper-password-manager
# keepingyouawake
# keeweb
# keka
# kekadefaultapp
# kern
# kext-updater
# kext-utility
# kextviewr
# key-codes
# keybase
# keyboard-cleaner
# keyboard-lock
# keyboard-maestro
# keyboardcleantool
# keycast
# keycastr
# keycue
# keyfinder
# keymanager
# keypad-layout
# keyshot
# keystore-explorer
# kicad
# kid3
# kindle
# kindle-comic-converter
# kindle-comic-creator
# kindle-previewer
# kinza
# kite
# kitematic
# kitty
# kiwi-for-g-suite
# kiwix
# kk7ds-python-runtime
# kkbox
# klatexformula
# klayout
# klokki
# kmbmpdc
# kmplayer
# knime
# knock
# knockknock
# knotes
# knox
# knuff
# koa11y
# koala
# kobo
# kode54-cog
# kodelife
# kodi
# komet
# komodo-edit
# komodo-ide
# kotlin-native
# krisp
# krita
# ksdiff
# kstars
# kube-cluster
# kube-forwarder
# kubecontext
# kubernetic
# kugoumusic
# kui
# kvirc
# lab
# lacona
# lando
# lantern
# laravel-kit
# lark
# lastfm
# lastpass
# latest
# latexdraw
# latexit
# launchbar
# launchcontrol
# launchpad-manager
# launchrocket
# launchy
# laverna
# lazarus
# lazpaint
# lazy
# lbry
# league-displays
# league-of-legends
# leanote
# leap-motion
# ledger-live
# leech
# lego-digital-designer
# lego-mindstorms-ev3
# lehreroffice
# leksah
# lektor
# lelivrescolairefr
# lens
# leocad
# lepton
# levelator
# librecad
# libreelec-usb-sd-creator
# libreoffice
# libreoffice-language-pack
# librepcb
# licecap
# license-control-center
# licensed
# liclipse
# lidarr
# lifesize
# lightgallery
# lighting
# lightpaper
# lightproxy
# lighttable
# lightworks
# lilypond
# lincastor
# line-bot-designer
# linear
# linear-linear
# linein
# lingo
# lingon-x
# linkliar
# linphone
# listen1
# litecoin
# liteicon
# liteide
# little-snitch
# littlesecrets
# livereload
# livetail
# liya
# lmms
# loading
# loaf
# local
# localdev
# localizationeditor
# lockdown
# lockrattler
# logdna-agent
# logdna-cli
# logicsniffer
# loginputmac
# logisim
# logisim-evolution
# logitech-presentation
# logmein-client
# logmein-hamachi
# logos
# lookin
# loom
# loopback
# losslesscut
# love
# lrtimelapse
# ltspice
# lulu
# lumen
# luminance-hdr
# lunar
# lunastudio
# luxmark
# luyten
# lyn
# lynkeos
# lynx
# lynxlet
# lyrics-master
# lyricsx
# lyx
# m3unify
# mac2imgur
# macbreakz
# macclean
# maccpuid
# maccy
# macdependency
# macdive
# macdjview
# macdown
# macdropany
# macfusion
# macfusion-ng
# macgamestore
# macgdbp
# macgesture
# machacha
# machg
# machoexplorer
# machoview
# maciasl
# macintosh-explorer
# macmediakeyforwarder
# macpar-deluxe
# macpass
# macpilot
# macs-fan-control
# macspice
# macsvg
# macterm
# mactex
# mactex-no-gui
# mactracker
# macupdate
# macupdater
# macvim
# macwinzipper
# macx-dvd-ripper-mac-free-edition
# macx-dvd-ripper-pro
# macx-video-converter-pro
# macx-youtube-downloader
# maczip4win
# maelstrom
# magic-launch
# magicavoxel
# magiccap
# magicplotpro
# magicplotstudent
# magicprefs
# mailbutler
# mailmaster
# mailmate
# mailplane
# mailspring
# maintenance
# majsoul-plus
# makehuman
# makemkv
# maltego
# malus
# malwarebytes
# mame
# mamp
# manageengine-mibbrowser
# manico
# manictime
# manta
# manuscripts
# manuskript
# mapillary-uploader
# mapture
# marathon
# marble
# marginnote
# mari0
# maria
# mark-text
# markdown-service-tools
# markdownmdimporter
# marked
# markright
# mars
# marsedit
# marshallofsound-google-play-music-player
# marta
# marvel
# marvin
# masscode
# massreplaceit
# master-password
# master-pdf-editor
# masterway-note
# mat
# mate-translate
# mater
# material-colors
# mathpix-snipping-tool
# mathtype
# matterhorn
# mattermost
# mattr-slate
# mauve
# mavensmate
# max
# mbed-studio
# mblock
# mcbopomofo
# mcedit
# mcgimp
# mdimagesizemdimporter
# mdrp
# media-center
# media-converter
# mediaelch
# mediahuman-audio-converter
# mediahuman-youtube-downloader
# mediainfo
# mediathekview
# meetingbar
# mega
# megacmd
# megahertz-knotes
# megasync
# meld
# mellow
# mellowplayer
# melodics
# melonbooksviewer
# memo
# memory
# memory-map
# mendeley
# mendeley-reference-manager
# menubar-colors
# menubar-countdown
# menubar-stats
# menucalendarclock-ical
# menumeters
# menutube
# merlin-project
# mesasqlite
# meshcommander
# meshlab
# meshmixer
# messenger-native
# messenger-unofficial
# meta
# metabase
# metashape
# metashapepro
# metasploit
# metaz
# meteorologist
# mgba
# mi
# mia-for-gmail
# michaelvillar-timer
# micro-snitch
# microblog
# microsoft-azure-storage-explorer
# microsoft-edge
# microsoft-excel
# microsoft-lync
# microsoft-office
# microsoft-outlook
# microsoft-powerpoint
# microsoft-r-open
# microsoft-teams
# microsoft-word
# middle
# middleclick
# midi-monitor
# midikeys
# midistroke
# miditrail
# mikogo
# miktex-console
# milanote
# milkman
# milkytracker
# mimecast
# min
# mindforger
# mindjet-mindmanager
# mindmaster
# minecraft
# minecraft-server
# minecraftpe
# mini-program-studio
# mini-vmac
# miniconda
# minishift
# minitimer
# minitube
# minizincide
# mipony
# miro
# mirrordisplays
# mirrorop
# mission-control-plus
# missive
# mist
# mit-app-inventor
# mixxx
# mjml
# mjolnir
# mkchromecast
# mks
# mkvtoolnix
# mkvtools
# mmex
# mnemosyne
# mob
# mobirise
# mobster
# mochi
# mockoon
# mockplus
# mockuuups-studio
# modelio
# modmove
# modulair
# moefe-google-translate
# mojibar
# molotov
# molsoftbrowser
# monal
# monero-wallet
# moneydance
# moneymoney
# moneywiz
# mongodb-compass
# mongodb-compass-isolated-edition
# mongodb-compass-readonly
# mongodbpreferencepane
# mongotron
# monitorcontrol
# monitorearth
# monity-helper
# mono-mdk
# monodraw
# monogame
# monolingual
# moom
# moonlight
# morkro-papyrus
# morpheus
# mos
# mosaic
# moscow-ml
# motrix
# mountain
# mountain-duck
# mounty
# mouse-locator
# mousepose
# movist
# movist-pro
# mp3gain-express
# mp3tag
# mp4tools
# mpeg-streamclip
# mplab-xc16
# mplab-xc32
# mplab-xc8
# mplabx-ide
# mplayer-osx-extended
# mplayerx
# mps
# mpv
# mqtt-explorer
# mqttfx
# mtmr
# mu-editor
# mucommander
# mudlet
# mullvadvpn
# multibit-hd
# multifirefox
# multimc
# multipass
# multipatch
# multiscan-3b
# multitouch
# mumble
# munki
# murus
# murus-menulet
# muruslogsvisualizer
# musaicfm
# muse
# museeks
# musescore
# music-manager
# musicbrainz-picard
# musictube
# mutespotifyads
# mutify
# muzzle
# mweb
# my-budget
# my-image-garden
# mycloud
# mycrypto
# mylio
# mymonero
# myphone
# mysides
# mysql-connector-python
# mysql-shell
# mysql-utilities
# mysqlworkbench
# nagbar
# nagstamon
# nally
# name-mangler
# namebench
# namechanger
# nano
# nanostudio
# nasas-eyes
# native-access
# nativedisplaybrightness
# natron
# nautilus
# navicat-data-modeler
# navicat-data-modeler-essentials
# navicat-for-mariadb
# navicat-for-mysql
# navicat-for-oracle
# navicat-for-postgresql
# navicat-for-sql-server
# navicat-for-sqlite
# navicat-premium
# navicat-premium-essentials
# nbtexplorer
# ncar-ncl
# ndm
# near-lock
# neo4j
# neofinder
# nestopia
# netbeans
# netbeans-cpp
# netbeans-java-ee
# netbeans-java-se
# netbeans-php
# netdownloadhelpercoapp
# neteasemusic
# nethackcocoa
# netiquette
# netlogo
# netnewswire
# netron
# netspot
# network-radar
# netxms-console
# next
# nextcloud
# nfov
# ngrok
# nheko
# nifty
# night-owl
# nightfall
# nightingale
# nightowl
# nimble-commander
# nimbus
# ninja-download-manager-ndm
# nisus-thesaurus
# nitroshare
# nndd
# no-ip-duc
# nocturnal
# nocturne
# nodebox
# nodeclipse
# noisebuddy
# noisy
# noisytyper
# nomachine
# nomachine-enterprise-client
# nomad
# noraswitch
# nordvpn
# nordvpn-teams
# nosleep
# nosql-workbench-for-amazon-dynamodb
# nosqlbooster-for-mongodb
# nosqlclient
# not-pacman
# not-tetris
# notable
# notational-velocity
# notebooks
# notedup
# noteplan
# noti
# notion
# noto
# noun-project
# novabench
# now
# now-tv-player
# noxappplayer
# nozbe
# nrlquaker-winbox
# nslogger
# nsregextester
# nteract
# ntfstool
# nuclear
# nucleo
# nuclino
# nulloy
# nullpomino
# numi
# nutstore
# nvalt
# nvidia-geforce-now
# nwjs
# nzbget
# nzbvortex
# objectivesharpie
# objektiv
# obs
# obs-virtualcam
# obsidian
# obyte
# ocenaudio
# oclint
# octomouse
# octoscreen
# odio
# odrive
# ogdesign-eagle
# olive
# omegat
# omnidazzle
# omnidb
# omnidisksweeper
# omnifocus
# omnigraffle
# omnioutliner
# omniplan
# omnipresence
# omniweb
# omx-ebooks
# ondesoft-audiobook-converter
# one-switch
# onecast
# onedrive
# onenote-importer-preview
# onepile
# oni
# onionshare
# onlyoffice
# onyx
# oolite
# open-ecard
# open-in-code
# openarena
# openaudible
# openbazaar
# openboard
# openboardview
# openconnect-gui
# opencore-configurator
# opencpn
# opendnsupdater
# openemu
# openframeworks
# openineditor-lite
# openinterminal
# openinterminal-lite
# openkey
# openlp
# openmsx
# openmtp
# openmw
# opennx
# openoffice
# openpht
# openra
# openrct2
# openrefine
# opensc
# openscad
# opensesame
# openshot-video-editor
# opensim
# opensong
# opentoonz
# openttd
# openvanilla
# openvisualtraceroute
# openvpn-connect
# openwebstart
# openxcom
# openzfs
# opera
# opera-mail
# opera-mobile-emulator
# opera-neon
# operadriver
# optimage
# optimal-layout
# oracle-jdk
# oracle-jdk-javadoc
# orange
# orca
# origami-studio
# origin
# orka
# oryoki
# osbuddy
# oscar
# oscilloscope
# osirix-quicklook
# osmc
# osquery
# osxfuse
# otter-browser
# otx
# outguess
# outline
# outline-manager
# outset
# outwit-hub
# overdrive-media-console
# overflow
# overkill
# oversight
# owasp-zap
# owncloud
# oxygen-xml-editor
# p4v
# pablodraw
# pacifist
# packages
# packet-peeper
# packetproxy
# packetsender
# pages-data-merge
# pagico
# paintbrush
# paintcode
# paletro
# panda
# pandora
# panic-unison
# panoply
# paparazzi
# paper
# papers
# paperspace
# papyrus
# paragon-extfs
# paragon-ntfs
# paragon-vmdk-mounter
# parallels
# parallels-access
# parallels-client
# parallels-toolbox
# parallels-virtualization-sdk
# paraview
# parse
# parsec
# parsehub
# particle-dev
# pashua
# password-assistant
# password-gorilla
# pastebot
# pastor
# patchwork
# path-finder
# paw
# pd
# pd-extended
# pd-l2ork
# pdf-converter-master
# pdf-expert
# pdf-images
# pdf-squeezer
# pdf-toolbox
# pdfelement
# pdfelement-express
# pdfextractor
# pdfkey-pro
# pdfpen
# pdfpenpro
# pdfsam-basic
# pdfshaver
# pdftotext
# peakhour
# penc
# pencil
# pencil2d
# pennywise
# perforce
# permute
# persepolis-download-manager
# pester
# pext
# pflists
# pg-commander
# pgadmin4
# phantomjs
# phew
# phocus
# phoenix
# phoenix-slides
# phonebrowse
# phoneclean
# phonegap
# phonerescue
# phonetrans
# photo-supreme-single-user
# photoninja
# photosweeper-x
# photosync
# photozoom-pro
# phpstorm
# physicseditor
# pibakery
# picgo
# piezo
# pikopixel
# pine
# pineapple
# pinegrow
# pingid
# pingmenu
# pingplotter
# pins
# pinta
# piskel
# pitchperfect
# pivy
# pixel-check
# pixel-picker
# pixelpeeper
# pixelsnap
# pixelstick
# plain-clip
# plan
# platelet
# platypus
# play
# playback
# playmemories-home
# playnow
# playonmac
# plecs-standalone
# plex
# plex-media-player
# plex-media-server
# plexamp
# pliim
# plistedit-pro
# plotdigitizer
# plover
# plug
# pluralsight
# pngyu
# pock
# pocket-casts
# podcastmenu
# podolski
# poedit
# poi
# pokemon-reborn
# pokemon-showdown
# pokerstars
# pokerth
# polar-bookshelf
# polycom-content
# polycom-realpresence
# polymail
# polyphone
# pomello
# pomodone
# pomolectron
# pomotodo
# pomotroid
# pongsaver
# popchar
# popclip
# popmaker
# popo
# popsql
# portfolioperformance
# porting-kit
# post-haste
# postbird
# postbox
# posterazor
# postgres
# postgrespreferencepane
# postico
# postman
# powder
# powder-player
# power-manager
# powerpanel
# powerphotos
# powershell
# powerword
# ppduck
# pppc-utility
# praat
# pref-setter
# preference-manager
# preferencecleaner
# preform
# prefs-editor
# prepros
# presentation
# pretzel
# prey
# prezi-classic
# prezi-next
# prince
# principle
# printopia
# printrun
# prismatik
# pritunl
# private-eye
# private-internet-access
# privatetunnel
# privatevpn
# prizmo
# pro-fit
# processing
# procexp
# proclaim
# product-hunt
# profilecreator
# profilemanager
# profind
# programmer-dvorak
# progressive-downloader
# projectlibre
# propresenter
# prosys-opc-ua-browser
# protege
# protonmail-bridge
# protonmail-unofficial
# protonvpn
# protopie
# provisioning
# provisionql
# prowritingaid
# proxifier
# proximity
# proxyman
# prudent
# prusaslicer
# psequel
# psi
# psi-plus
# psychopy
# publii
# publish-or-perish
# pullover
# pulse-sms
# punto-switcher
# puppetry
# purei-play
# purevpn
# pusher
# putio-adder
# puush
# puzzles
# pwnagetool
# pycharm
# pycharm-ce
# pycharm-ce-with-anaconda-plugin
# pycharm-edu
# pycharm-with-anaconda-plugin
# pyfa
# pym-player
# pynsource
# pyzo
# qbittorrent
# qblocker
# qbserve
# qcad
# qcma
# qctools
# qdesktop
# qdslrdashboard
# qfinder-pro
# qgis
# qgroundcontrol
# qingg
# qiyimedia
# ql-ansilove
# qlab
# qladdict
# qlc-plus
# qlcolorcode
# qlcommonmark
# qldds
# qlfits
# qlgradle
# qlimagesize
# qlmarkdown
# qlmobi
# qlnetcdf
# qlplayground
# qlprettypatch
# qlrest
# qlstephen
# qlswift
# qlvideo
# qmoji
# qnapi
# qobuz
# qownnotes
# qq
# qqbrowser
# qqlive
# qqmacmgr
# qqmusic
# qqplayer
# qr-journal
# qsync-client
# qsyncthingtray
# qt-creator
# qt-design-studio
# qt3dstudio
# qtox
# qtpass
# qtspim
# qtum
# qtvlm
# quail
# quakespasm
# quassel
# quassel-client
# quaternion
# querious
# questrade-iq-edge
# quickbooks
# quickbooks-online
# quickboot
# quicken
# quickgeojson
# quickhash
# quickhue
# quickjson
# quickkeyextension
# quicklook-csv
# quicklook-json
# quicklook-pat
# quicklook-pfm
# quicklookapk
# quicklookase
# quicknfo
# quicksilver
# quicksync
# quickwords
# quik
# quip
# quiterss
# quitter
# quodlibet
# qutebrowser
# qv2ray
# qview
# qxmledit
# qyooo
# r
# r-name
# rabbitmq
# race-into-space
# racket
# racket-cs
# radarr
# radiant-player
# radio-silence
# raindropio
# rambox
# ramme
# ransomwhere
# rapidminer-studio
# rapidweaver
# rar
# raspberry-pi-imager
# raven
# raven-reader
# raw-photo-processor
# rawtherapee
# razorsql
# rclone-browser
# rcloneosx
# rcse
# react-native-debugger
# react-proto
# react-studio
# reactotron
# realforce
# realm-studio
# reaper
# receiptquicklook
# receipts
# recents
# recordit
# recovery-disk-assistant
# rectangle
# red
# red-eye
# redcine-x-pro
# redeclipse
# redis
# redisinsight
# refined-github-safari
# reflector
# regexhibit
# reggy
# reikey
# rekordbox
# rember
# remember-the-milk
# remote-buddy
# remote-desktop-manager
# remote-desktop-manager-free
# remoteviewer
# remotix-agent
# renamer
# renpy
# repetier-host
# rescuetime
# residualvm
# resilio-sync
# resolume-arena
# resolutionator
# responsively
# resxtreme
# retinizer
# retro-virtual-machine
# retroarch
# retroarch-metal
# retrobatch
# retroshare
# reunion
# reveal
# revisions
# rhinoceros
# ricochet
# rider
# ridibooks
# rightfont
# rightzoom
# ring
# ringcentral
# ringcentral-classic
# ringcentral-meetings
# ringcentral-phone
# ringtones
# ripcord
# ripit
# roaringapps
# robo-3t
# robofont
# roboform
# rocket
# rocket-chat
# rocket-typist
# rocks-n-diamonds
# rodeo
# roku-remote-tool
# rolisteam
# roon
# rosaimagewriter
# rotato
# routebuddy
# routeconverter
# rowanj-gitx
# rowmote-helper
# royal-tsx
# rpn-scientific
# rpvoip
# rq
# rrcc
# rss
# rssowl
# rstudio
# rsyncosx
# rubitrack-pro
# rubymine
# rubymotion
# runescape
# runjs
# runway
# ryver
# sabaki
# sabnzbd
# safeincloud-password-manager
# sage
# sameboy
# santa
# saoimageds9
# sapmachine-jdk
# satellite-eyes
# sauce-connect
# sauerbraten
# save-hollywood
# scala-ide
# scaleft
# scansion
# scap-workbench
# scapple
# scenebuilder
# schism-tracker
# scidavis
# scidvsmac
# scihubeva
# scilab
# scout
# scratch
# screaming-frog-seo-spider
# screen
# screencast
# screenflick
# screenflow
# screens
# screens-connect
# scribus
# script-debugger
# scriptql
# scrivener
# scroll-reverser
# scrooo
# scrutiny
# scummvm
# sdformatter
# sdrdx
# seadrive
# seafile-client
# seaglass
# seamonkey
# seashore
# second-life-viewer
# secretive
# secure-pipes
# securesafe
# securid
# security-growler
# securityspy
# segger-embedded-studio-for-arm
# sejda-pdf
# sekey
# selfcontrol
# semulov
# sencha
# send-anywhere
# send-to-kindle
# sensei
# sensiblesidebuttons
# sentinel
# senuti
# sequel-ace
# sequel-pro
# sequential
# serial
# serial-tools
# serviio
# servo
# servpane
# session
# session-manager-plugin
# setapp
# sf-symbols
# sfdx
# shades
# shadow
# shadowsocksx
# shadowsocksx-ng
# shadowsocksx-ng-r
# shapes
# sharemouse
# sharepod
# shellhere
# sherlock
# shiba
# shift
# shiftit
# shifty
# shimeike-formulatepro
# shimo
# shiori
# shoes
# shortcat
# shortcutdetective
# shortcuts
# shotcut
# showhiddenfiles
# showyedge
# shrinkit
# shupapan
# shutter-encoder
# shuttle
# sia-ui
# sickbeard-anime
# sidekick
# sidenotes
# sidequest
# sidestep
# sigdigger
# sigil
# sigilium-email-signatures
# signal
# sigviewer
# silentknight
# silo
# silverlight
# sim-daltonism
# simpholders
# simple-comic
# simplecap
# simplediagrams
# simplefloatingclock
# simplenote
# simplesynth
# simplistic
# simply-fortran
# simsim
# singularity
# sip
# sipgate-softphone
# sirimote
# sitebulb
# sixtyforce
# sizeup
# sizzy
# skala-preview
# sketch
# sketch-toolbox
# sketchbook
# sketchpacks
# sketchup
# sketchup-pro
# skim
# skitch
# skreenics
# skybox
# skyfonts
# skype
# skype-for-business
# skypewebplugin
# slack
# slate
# sleipnir
# slic3r
# slicer
# slik
# slimbatterymonitor
# slingplayer
# slite
# sloth
# smallpdf
# smart-converter-pro
# smartgit
# smartsvn
# smartsynchronize
# smcfancontrol
# smlnj
# smoothscroll
# smooze
# snagit
# snapndrag
# snappy
# sneek
# snes9x
# snip
# snipaste
# snowflake-snowsql
# snwe
# soapui
# socket-io-tester
# sococo
# soda-player
# soduto
# sofa-server
# softmaker-freeoffice
# softorino-youtube-converter
# softraid
# softu2f
# softube-central
# sogouinput
# solvespace
# sonarr
# sonarr-menu
# sonic-pi
# sonic-visualiser
# sonoair
# soqlxplorer
# soulseek
# soulver
# sound-control
# sound-siphon
# soundboosterlite
# soundcleod
# soundcloud-downloader
# soundflower
# soundflowerbed
# soundsource
# sourcenote
# sourcetrail
# sourcetree
# spacelauncher
# spaceradar
# spamsieve
# spark
# sparkle
# sparkleshare
# spatial
# spatterlight
# spechtlite
# spectacle
# spectacle-editor
# spectrum
# spectx
# speedcrunch
# speedify
# spek
# spideroak-share
# spideroakone
# spillo
# spires
# splashtop-business
# splashtop-personal
# splashtop-streamer
# splayer
# splice
# splitshow
# spotifree
# spotify
# spotify-now-playing
# spotmenu
# spotspot
# springtoolsuite
# sql-power-architect-jdbc
# sql-tabs
# sqlectron
# sqleditor
# sqlexplorer
# sqlitemanager
# sqlitestudio
# sqlpro-for-mssql
# sqlpro-for-mysql
# sqlpro-for-postgres
# sqlpro-for-sqlite
# sqlpro-studio
# sqlworkbenchj
# squadanimatorgaa
# squadanimatorrugby
# squadanimatorsoccer
# squeak
# squidman
# squirrel
# squirrelsql
# srware-iron
# ssh-config-editor
# ssh-tunnel-manager
# ssokit
# stack
# stack-exchange-notifier
# stack-stack
# stand
# standard-notes
# starcraft
# starleaf
# startninja
# startupizer
# staruml
# station
# stationtv-link
# stats
# statusfy
# stay
# steam
# steamcmd
# steermouse
# stella
# stellarium
# stepmania
# steveschow-gfxcardstatus
# stoplight-studio
# storyboarder
# strange-flesh
# strawberry
# streamlabs-obs
# streamlink-twitch-gui
# stremio
# stretchly
# stringsfile
# strongvpn
# stubbymanager
# studio-3t
# studiolinkstandalone
# subethaedit
# subgit
# subler
# sublercli
# sublime-merge
# sublime-text
# subnetcalc
# subsurface
# subsync
# subtitle-master
# subtitles
# subtools
# suitcase-fusion
# sunlogincontrol
# sunsama
# sunvox
# superbeam
# supercollider
# superduper
# superhuman
# superproductivity
# supersync
# supertuxkart
# surfeasy-vpn
# surge
# surge-synthesizer
# suspicious-package
# svgcleaner
# svnx
# sweet-home3d
# swift
# swift-explorer
# swift-publisher
# swiftdefaultappsprefpane
# swiftformat-for-xcode
# swiftpm-catalog
# swiftstack-client
# swifty
# swiftybeaver
# swimat
# swinsian
# swish
# switch
# switchhosts
# switchkey
# switchresx
# symboliclinker
# synalyze-it-pro
# sync
# sync-my-l2p
# syncmate
# syncovery
# syncplay
# syncterm
# syncthing
# synergy
# synfigstudio
# synology-chat
# synology-note-station-client
# syntax-highlight
# synthesia
# sysdig-inspect
# sysex-librarian
# table-tool
# tableau
# tableau-prep
# tableau-public
# tableau-reader
# tableflip
# tableplus
# tabula
# tad
# tag
# tagalicious
# tagger
# tagspaces
# tales-of-majeyal
# talon
# tandem
# tap-forms
# taskade
# taskexplorer
# taskpaper
# taskwarrior-pomodoro
# tastyworks
# tau
# tbe
# tbs-studio
# tcl
# td-agent
# teacode
# teambition
# teamdrive
# teamspeak-client
# teamviewer
# teamviewer-host
# teamviewer-quickjoin
# teamviewer-quicksupport
# teamwire
# teensy
# teeworlds
# telavox-flow
# telegram
# telegram-desktop
# tempo
# tencent-lemon
# tencent-meeting
# tenor
# termhere
# terminology
# terminus
# termius
# tex-live-utility
# texmacs
# texmaker
# texpad
# texshop
# texstudio
# textadept
# textbar
# textexpander
# textmate
# texts
# textual
# texturepacker
# texworks
# tg-pro
# th-makerx
# the-archive-browser
# the-battle-for-wesnoth
# the-cheat
# the-clock
# the-tagger
# the-unarchiver
# thebrain
# thedesk
# themeengine
# there
# therm
# thetube
# thingsmacsandboxhelper
# thinkorswim
# thonny
# thonny-xxl
# thor
# thorium
# thought-train
# threads
# thumbsup
# thunder
# thunderbird
# thyme
# ti-connect-ce
# tibco-jaspersoft-studio
# tickeys
# ticktick
# tidal
# tiddly
# tidepool-uploader
# tifig
# tiger-trade
# tigervnc-viewer
# tigervpn
# tikz-editor
# tikzit
# tiled
# tiles
# time-lapse-assembler
# time-out
# time-sink
# time-tracker
# timecamp
# timelane
# timely
# timemachineeditor
# timemator
# timer
# timestamp
# timeular
# timing
# timings
# tinderbox
# tinkerwell
# tiny-player
# tinymediamanager
# tinypng4mac
# tip
# tipp10
# tla-plus-toolbox
# tlv
# tn3270-x
# tnefs-enough
# today-scripts
# todometer
# todos
# todotxt
# todour
# tofu
# toinane-colorpicker
# tomighty
# tongbu
# tonido
# toontown-rewritten
# topcat
# toptracker
# tor-browser
# torguard
# torrent-file-editor
# tortoisehg
# touch-bar-pong
# touch-bar-simulator
# touchbarserver
# touchdesigner
# touchosc-bridge
# touchosc-editor
# touchswitcher
# tower
# townwifi
# tracks-live
# trader-workstation
# trailer
# trainerroad
# tranquility
# transmission
# transmission-remote-gui
# transmit
# transmit-disk
# transnomino
# transocks
# transtype
# trash-it
# trayplay
# treesheets
# tresorit
# trezor-bridge
# tribler
# trilium-notes
# trim-enabler
# trinity
# triplecheese
# tripmode
# trolcommander
# tropy
# trufont
# ttscoff-mmd-quicklook
# tuck
# tuneinstructor
# tuneskit-m4v-converter
# tunnelbear
# tunnelblick
# tuntap
# tuple
# turbo-boost-switcher
# turbovnc-viewer
# turtl
# tusk
# tutanota
# tuxera-ntfs
# tuxguitar
# tv-browser
# tvrenamer
# tweet-tray
# tweetbot
# tweeten
# twine
# twist
# twitch
# twonkyserver
# tyke
# typeface
# typeit4me
# typinator
# typora
# tysimulator
# ubar
# uberconference
# ubersicht
# uc-one
# udeler
# udig
# ueli
# ui-browser
# ukelele
# ukrainian-unicode-layout
# ultimaker-cura
# ultimate
# ultimate-control
# ultrastardeluxe
# unclutter
# uncolored
# uncrustifyx
# understand
# unetbootin
# unicodechecker
# unified-remote
# uninstallpkg
# unison
# unite
# unity
# unity-android-support-for-editor
# unity-download-assistant
# unity-hub
# unity-ios-support-for-editor
# unity-lumin-support-for-editor
# unity-standard-assets
# unity-web-player
# unity-webgl-support-for-editor
# unity-windows-support-for-editor
# universal-media-server
# unlox
# unpkg
# unshaky
# upic
# upm
# upterm
# upwork
# usage
# usb-overdrive
# use-engine
# utc-menu-clock
# utools
# utox
# uu-booster
# uxprotect
# v2rayu
# v2rayx
# vagrant
# vagrant-manager
# vagrant-vmware-utility
# valentina-studio
# valley
# vallum
# vanilla
# vapor
# vassal
# vcv-rack
# vectr
# vellum
# veonim
# veracrypt
# versions
# vesta
# veusz
# via
# viber
# vidcutter
# videobox
# videostream
# vidrio
# vidyo
# vienna
# vimediamanager
# vimr
# vin047-abgx360
# vip-access
# virtual-ii
# virtualbox
# virtualbox-extension-pack
# virtualc64
# virtualgl
# virtualhere
# virtualhereserver
# virtualhostx
# virustotaluploader
# viscosity
# visicut
# visit
# visual
# visual-paradigm
# visual-paradigm-ce
# visual-studio
# visual-studio-code
# visualboyadvance-m
# visualvm
# vitalsource-bookshelf
# vitamin-r
# vivaldi
# vivi
# vk-messenger
# vlc
# vlc-webplugin
# vlcstreamer
# vmpk
# vmware-fusion
# vmware-horizon-client
# vnc-server
# vnc-viewer
# vnote
# voicemac
# voikkospellservice
# volt
# voodoopad
# vorta
# vox
# vox-preferences-pane
# voxql
# vpn-enabler
# vrep
# vrew
# vscodium
# vsee
# vu
# vuescan
# vuze
# vv
# vyprvpn
# vysor
# wacom-inkspace
# wail
# wakeonlan
# wallpaper-wizard
# waltr
# wanna
# warsow
# warzone-2100
# wasabi-wallet
# watchguard-mobile-vpn-with-ssl
# waterfox
# waterfox-current
# wavebox
# waves-central
# wavesurfer
# wavtap
# web-sharing
# webarchiveextractor
# webcamoid
# webcatalog
# webex-meetings
# webex-nbr-player
# webex-teams
# webex-wrf-player
# webpack-dashboard
# webplotdigitizer
# webpquicklook
# webrecorder-player
# website-watchman
# webstorm
# webtorrent
# webviewscreensaver
# wechat
# wechatwebdevtools
# wechatwork
# weiyun
# weka
# welly
# wercker
# wercker-cli
# wewechat
# wey
# whale
# whalebird
# whatroute
# whatsapp
# whatsize
# whatsyoursign
# whichspace
# whoozle-android-file-transfer
# wickrme
# widelands
# wifi-explorer
# wifispoof
# winclone
# window-switch
# windows95
# winds
# windscribe
# wine-stable
# wingpersonal
# wings3d
# wintertime
# winzip
# wire
# wireframe-sketcher
# wireshark
# wireshark-chmodbpf
# witch
# wiznote
# wjoy
# wkhtmltopdf
# wonderfultools-screensaver
# wondershare-filmora
# wordpresscom
# wordservice
# workbench
# workflowy
# workplace-chat
# workspaces
# wormhole
# wowmatrix
# wpsoffice
# wraparound
# wrike
# writefull
# writemapper
# writer
# wwdc
# wwdcsrt
# wxcrafter
# x-mirage
# x-moto
# x-swiftformat
# x2goclient
# xact
# xamarin
# xamarin-android
# xamarin-ios
# xamarin-mac
# xamarin-profiler
# xamarin-studio
# xamarin-workbooks
# xampp
# xampp-vm
# xaos
# xbench
# xca
# xcodeclangformat
# xctu
# xdm
# xee
# xiami
# ximalaya
# xit
# xld
# xlink-kai
# xlplayer
# xmind
# xmind-zen
# xmplify
# xnconvert
# xnviewmp
# xoctave
# xonotic
# xpra
# xquartz
# xrg
# xscope
# xscreensaver
# xtorrent
# yacreader
# yakyak
# yam-display
# yammer
# yandex
# yandex-cloud-cli
# yandex-disk
# yandexradio
# yate
# yed
# yemuzip
# yep
# yinxiangbiji
# yo
# yoda
# yojimbo
# youdaodict
# youdaonote
# youku
# youll-never-take-me-alive
# youtrack-workflow
# youtube-to-mp3
# yt-music
# ytmdesktop-youtube-music
# yu-writer
# yy
# yyets
# zalo
# zandronum
# zappy
# zazu
# zdoom
# zeebe-modeler
# zenbeats
# zenmap
# zenmate-vpn
# zeplin
# zerobranestudio
# zeronet
# zerotier-one
# zesarux
# zettelkasten
# zettlr
# zipcleaner
# zoc
# zoho-docs
# zoho-mail
# zoho-workdrive
# zoolz
# zoom
# zoom-for-it-admins
# zoomin
# zoomus
# zoomus-outlook-plugin
# zotero
# zterm
# zulip
# zulu
# zwift
# zxpinstaller
# ==> Deleted Casks
# 8x8-video-meetings         ghost                      riot
# alephone                   hipchat                    scope
# blue-jeans                 imaging-edge               sleepyhead
# borgbackup                 imgur                      sopcast
# box-edit                   intelliscape-caffeine      sound-blaster-command
# cocoscreator               kindlegen                  toggl
# cutbox                     lunchy                     trojan-qt5
# daemon-tools               mongodb-compass-community  uniconverter
# daily-english-listening    myworkspace                webponize
# dropbox-encore             nimble                     x48
# enolsoft-chm-view          obinslab-starter           xmrouter
# filemaker-pro-advanced     phiewer                    yourkit-java-profiler
# fme-desktop                podman
# Warning: wget 1.20.3_2 is already installed and up-to-date
# To reinstall 1.20.3_2, run `brew reinstall wget`
# --2020-09-10 17:09:22--  http://msvocds.blob.core.windows.net/annotations-1-0-3/captions_train-val2014.zip
# Resolving msvocds.blob.core.windows.net (msvocds.blob.core.windows.net)... 52.176.224.96
# Connecting to msvocds.blob.core.windows.net (msvocds.blob.core.windows.net)|52.176.224.96|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19673183 (19M) [application/octet-stream Charset=UTF-8]
# Saving to: ‘./data_dir/captions_train-val2014.zip’
#
# captions_train-val2 100%[===================>]  18.76M  1.02MB/s    in 23s
#
# 2020-09-10 17:09:46 (848 KB/s) - ‘./data_dir/captions_train-val2014.zip’ saved [19673183/19673183]
#
# --2020-09-10 17:09:46--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.1.156
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.1.156|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘./data_dir/train2014.zip’
#
# train2014.zip         9%[>                   ]   1.17G  1.47MB/s    eta 2h 38m

# %% [markdown]
# ## import dependencies

# %%
import os
import nltk
import pickle
import numpy as np
from PIL import Image
from collections import Counter
from pycocotools.coco import COCO
import matplotlib.pyplot as plt
 
import torch
import torch.nn as nn
import torch.utils.data as data
from torchvision import transforms
import torchvision.models as models
import torchvision.transforms as transforms
from torch.nn.utils.rnn import pack_padded_sequence

# %%
nltk.download('punkt')

# %% [markdown]
# ## build vocab

# %%
class Vocab(object):
    """Simple vocabulary wrapper."""
    def __init__(self):
        self.w2i = {}
        self.i2w = {}
        self.index = 0
 
    def __call__(self, token):
        if not token in self.w2i:
            return self.w2i['<unk>']
        return self.w2i[token]
 
    def __len__(self):
        return len(self.w2i)
    def add_token(self, token):
        if not token in self.w2i:
            self.w2i[token] = self.index
            self.i2w[self.index] = token
            self.index += 1

def build_vocabulary(json, threshold):
    """Build a simple vocabulary wrapper."""
    coco = COCO(json)
    counter = Counter()
    ids = coco.anns.keys()
    for i, id in enumerate(ids):
        caption = str(coco.anns[id]['caption'])
        tokens = nltk.tokenize.word_tokenize(caption.lower())
        counter.update(tokens)
 
        if (i+1) % 1000 == 0:
            print("[{}/{}] Tokenized the captions.".format(i+1, len(ids)))
 
    # If the word frequency is less than 'threshold', then the word is discarded.
    tokens = [token for token, cnt in counter.items() if cnt >= threshold]
 
    # Create a vocab wrapper and add some special tokens.
    vocab = Vocab()
    vocab.add_token('<pad>')
    vocab.add_token('<start>')
    vocab.add_token('<end>')
    vocab.add_token('<unk>')
 
    # Add the words to the vocabulary.
    for i, token in enumerate(tokens):
        vocab.add_token(token)
    return vocab
 
vocab = build_vocabulary(json='data_dir/annotations/captions_train2014.json', threshold=4)
vocab_path = './data_dir/vocabulary.pkl'
with open(vocab_path, 'wb') as f:
    pickle.dump(vocab, f)
print("Total vocabulary size: {}".format(len(vocab)))
print("Saved the vocabulary wrapper to '{}'".format(vocab_path))

# %% [markdown]
# ## resize images

# %%
def reshape_image(image, shape):
    """Resize an image to the given shape."""
    return image.resize(shape, Image.ANTIALIAS)
 
def reshape_images(image_path, output_path, shape):
    """Reshape the images in 'image_path' and save into 'output_path'."""
    if not os.path.exists(output_path):
        os.makedirs(output_path)
 
    images = os.listdir(image_path)
    num_im = len(images)
    for i, im in enumerate(images):
        with open(os.path.join(image_path, im), 'r+b') as f:
            with Image.open(f) as image:
                image = reshape_image(image, shape)
                image.save(os.path.join(output_path, im), image.format)
        if (i+1) % 100 == 0:
            print ("[{}/{}] Resized the images and saved into '{}'."
                   .format(i+1, num_im, output_path))

image_path = './data_dir/train2014/'
output_path = './data_dir/resized_images/'
image_shape = [256, 256]
reshape_images(image_path, output_path, image_shape)

# %% [markdown]
# ## instantiate data loader

# %%
class CustomCocoDataset(data.Dataset):
    """COCO Custom Dataset compatible with torch.utils.data.DataLoader."""
    def __init__(self, data_path, coco_json_path, vocabulary, transform=None):
        """Set the path for images, captions and vocabulary wrapper.
        
        Args:
            root: image directory.
            json: coco annotation file path.
            vocab: vocabulary wrapper.
            transform: image transformer.
        """
        self.root = data_path
        self.coco_data = COCO(coco_json_path)
        self.indices = list(self.coco_data.anns.keys())
        self.vocabulary = vocabulary
        self.transform = transform
 
    def __getitem__(self, idx):
        """Returns one data pair (image and caption)."""
        coco_data = self.coco_data
        vocabulary = self.vocabulary
        annotation_id = self.indices[idx]
        caption = coco_data.anns[annotation_id]['caption']
        image_id = coco_data.anns[annotation_id]['image_id']
        image_path = coco_data.loadImgs(image_id)[0]['file_name']
 
        image = Image.open(os.path.join(self.root, image_path)).convert('RGB')
        if self.transform is not None:
            image = self.transform(image)
 
        # Convert caption (string) to word ids.
        word_tokens = nltk.tokenize.word_tokenize(str(caption).lower())
        caption = []
        caption.append(vocabulary('<start>'))
        caption.extend([vocabulary(token) for token in word_tokens])
        caption.append(vocabulary('<end>'))
        ground_truth = torch.Tensor(caption)
        return image, ground_truth
 
    def __len__(self):
        return len(self.indices)
 
 
def collate_function(data_batch):
    """Creates mini-batch tensors from the list of tuples (image, caption).
    
    We should build custom collate_fn rather than using default collate_fn, 
    because merging caption (including padding) is not supported in default.
    Args:
        data: list of tuple (image, caption). 
            - image: torch tensor of shape (3, 256, 256).
            - caption: torch tensor of shape (?); variable length.
    Returns:
        images: torch tensor of shape (batch_size, 3, 256, 256).
        targets: torch tensor of shape (batch_size, padded_length).
        lengths: list; valid length for each padded caption.
    """
    # Sort a data list by caption length (descending order).
    data_batch.sort(key=lambda d: len(d[1]), reverse=True)
    imgs, caps = zip(*data_batch)
 
    # Merge images (from list of 3D tensors to 4D tensor).
    # Originally, imgs is a list of <batch_size> number of RGB images with dimensions (3, 256, 256)
    # This line of code turns it into a single tensor of dimensions (<batch_size>, 3, 256, 256)
    imgs = torch.stack(imgs, 0)
 
    # Merge captions (from list of 1D tensors to 2D tensor), similar to merging of images donw above.
    cap_lens = [len(cap) for cap in caps]
    tgts = torch.zeros(len(caps), max(cap_lens)).long()
    for i, cap in enumerate(caps):
        end = cap_lens[i]
        tgts[i, :end] = cap[:end]        
    return imgs, tgts, cap_lens
 
def get_loader(data_path, coco_json_path, vocabulary, transform, batch_size, shuffle, num_workers):
    """Returns torch.utils.data.DataLoader for custom coco dataset."""
    # COCO caption dataset
    coco_dataser = CustomCocoDataset(data_path=data_path,
                       coco_json_path=coco_json_path,
                       vocabulary=vocabulary,
                       transform=transform)
    
    # Data loader for COCO dataset
    # This will return (images, captions, lengths) for each iteration.
    # images: a tensor of shape (batch_size, 3, 224, 224).
    # captions: a tensor of shape (batch_size, padded_length).
    # lengths: a list indicating valid length for each caption. length is (batch_size).
    custom_data_loader = torch.utils.data.DataLoader(dataset=coco_dataser, 
                                              batch_size=batch_size,
                                              shuffle=shuffle,
                                              num_workers=num_workers,
                                              collate_fn=collate_function)
    return custom_data_loader

# %% [markdown]
# ## model definition

# %%
class CNNModel(nn.Module):
    def __init__(self, embedding_size):
        """Load the pretrained ResNet-152 and replace top fc layer."""
        super(CNNModel, self).__init__()
        resnet = models.resnet152(pretrained=True)
        module_list = list(resnet.children())[:-1]      # delete the last fc layer.
        self.resnet_module = nn.Sequential(*module_list)
        self.linear_layer = nn.Linear(resnet.fc.in_features, embedding_size)
        self.batch_norm = nn.BatchNorm1d(embedding_size, momentum=0.01)
        
    def forward(self, input_images):
        """Extract feature vectors from input images."""
        with torch.no_grad():
            resnet_features = self.resnet_module(input_images)
        resnet_features = resnet_features.reshape(resnet_features.size(0), -1)
        final_features = self.batch_norm(self.linear_layer(resnet_features))
        return final_features
 
 
class LSTMModel(nn.Module):
    def __init__(self, embedding_size, hidden_layer_size, vocabulary_size, num_layers, max_seq_len=20):
        """Set the hyper-parameters and build the layers."""
        super(LSTMModel, self).__init__()
        self.embedding_layer = nn.Embedding(vocabulary_size, embedding_size)
        self.lstm_layer = nn.LSTM(embedding_size, hidden_layer_size, num_layers, batch_first=True)
        self.linear_layer = nn.Linear(hidden_layer_size, vocabulary_size)
        self.max_seq_len = max_seq_len
        
    def forward(self, input_features, capts, lens):
        """Decode image feature vectors and generates captions."""
        embeddings = self.embedding_layer(caps)
        embeddings = torch.cat((input_features.unsqueeze(1), embeddings), 1)
        lstm_input = pack_padded_sequence(embeddings, lens, batch_first=True) 
        hidden_variables, _ = self.lstm_layer(lstm_input)
        model_outputs = self.linear_layer(hidden_variables[0])
        return model_outputs
    
    def sample(self, input_features, lstm_states=None):
        """Generate captions for given image features using greedy search."""
        sampled_indices = []
        lstm_inputs = input_features.unsqueeze(1)
        for i in range(self.max_seq_len):
            hidden_variables, lstm_states = self.lstm_layer(lstm_inputs, lstm_states)          # hiddens: (batch_size, 1, hidden_size)
            model_outputs = self.linear_layer(hidden_variables.squeeze(1))            # outputs:  (batch_size, vocab_size)
            _, predicted_outputs = model_outputs.max(1)                        # predicted: (batch_size)
            sampled_indices.append(predicted_outputs)
            lstm_inputs = self.embedding_layer(predicted_outputs)                       # inputs: (batch_size, embed_size)
            lstm_inputs = lstm_inputs.unsqueeze(1)                         # inputs: (batch_size, 1, embed_size)
        sampled_indices = torch.stack(sampled_indices, 1)                # sampled_ids: (batch_size, max_seq_length)
        return sampled_indices

# %% [markdown]
# ## training loop

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# Create model directory
if not os.path.exists('models_dir/'):
    os.makedirs('models_dir/')

    
# Image preprocessing, normalization for the pretrained resnet
transform = transforms.Compose([ 
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip(), 
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), 
                         (0.229, 0.224, 0.225))])


# Load vocabulary wrapper
with open('data_dir/vocabulary.pkl', 'rb') as f:
    vocabulary = pickle.load(f)

    
# Build data loader
custom_data_loader = get_loader('data_dir/resized_images', 'data_dir/annotations/captions_train2014.json', vocabulary, 
                         transform, 128,
                         shuffle=True, num_workers=2) 


# Build the models
encoder_model = CNNModel(256).to(device)
decoder_model = LSTMModel(256, 512, len(vocabulary), 1).to(device)
 
    
# Loss and optimizer
loss_criterion = nn.CrossEntropyLoss()
parameters = list(decoder_model.parameters()) + list(encoder_model.linear_layer.parameters()) + list(encoder_model.batch_norm.parameters())
optimizer = torch.optim.Adam(parameters, lr=0.001)


# Train the models
total_num_steps = len(custom_data_loader)
for epoch in range(5):
    for i, (imgs, caps, lens) in enumerate(custom_data_loader):
 
        # Set mini-batch dataset
        imgs = imgs.to(device)
        caps = caps.to(device)
        tgts = pack_padded_sequence(caps, lens, batch_first=True)[0]
 
        # Forward, backward and optimize
        feats = encoder_model(imgs)
        outputs = decoder_model(feats, caps, lens)
        loss = loss_criterion(outputs, tgts)
        decoder_model.zero_grad()
        encoder_model.zero_grad()
        loss.backward()
        optimizer.step()
 
        # Print log info
        if i % 10 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Perplexity: {:5.4f}'
                  .format(epoch, 5, i, total_num_steps, loss.item(), np.exp(loss.item()))) 
 
        # Save the model checkpoints
        if (i+1) % 1000 == 0:
            torch.save(decoder_model.state_dict(), os.path.join(
                'models_dir/', 'decoder-{}-{}.ckpt'.format(epoch+1, i+1)))
            torch.save(encoder_model.state_dict(), os.path.join(
                'models_dir/', 'encoder-{}-{}.ckpt'.format(epoch+1, i+1)))

# %% [markdown]
# ## predict caption

# %%
image_file_path = 'sample.jpg'
 

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
 

def load_image(image_file_path, transform=None):
    img = Image.open(image_file_path).convert('RGB')
    img = img.resize([224, 224], Image.LANCZOS)
    
    if transform is not None:
        img = transform(img).unsqueeze(0)
    
    return img
 

# Image preprocessing
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), 
                         (0.229, 0.224, 0.225))])


# Load vocabulary wrapper
with open('data_dir/vocabulary.pkl', 'rb') as f:
    vocabulary = pickle.load(f)


# Build models
encoder_model = CNNModel(256).eval()  # eval mode (batchnorm uses moving mean/variance)
decoder_model = LSTMModel(256, 512, len(vocabulary), 1)
encoder_model = encoder_model.to(device)
decoder_model = decoder_model.to(device)


# Load the trained model parameters
encoder_model.load_state_dict(torch.load('models_dir/encoder-2-3000.ckpt'))
decoder_model.load_state_dict(torch.load('models_dir/decoder-2-3000.ckpt'))


# Prepare an image
img = load_image(image_file_path, transform)
img_tensor = img.to(device)


# Generate an caption from the image
feat = encoder_model(img_tensor)
sampled_indices = decoder_model.sample(feat)
sampled_indices = sampled_indices[0].cpu().numpy()          # (1, max_seq_length) -> (max_seq_length)


# Convert word_ids to words
predicted_caption = []
for token_index in sampled_indices:
    word = vocabulary.i2w[token_index]
    predicted_caption.append(word)
    if word == '<end>':
        break
predicted_sentence = ' '.join(predicted_caption)


# Print out the image and the generated caption
print (predicted_sentence)
img = Image.open(image_file_path)
plt.imshow(np.asarray(img))
